# %% [markdown]
# # Women's Starters

# %% [markdown]
# Get ratings of each team's starters in a given year. This file needs to be ran for every relevant year.

# %% [markdown]
# ### Web Scraping

# %% [markdown]
# Fair warning that this program unfortunately takes a very long time to run due to web scraping limits set by Sports Reference

# %%
import pandas as pd
import numpy as np
import time

season = 2012

df_active_teams = pd.read_html('https://www.sports-reference.com/cbb/schools/index.html')[0]
time.sleep(2)

df_active_teams = df_active_teams.loc[~df_active_teams['School'].isin([np.NaN, 'School']), :].reset_index(drop=True)

df_active_teams['From'] = pd.to_numeric(df_active_teams['From'], errors='coerce')
df_active_teams['To'] = pd.to_numeric(df_active_teams['To'], errors='coerce')

df_active_teams = df_active_teams.loc[(df_active_teams['To'] >= season) & (df_active_teams['From'] <= season), :].reset_index(drop=True)

if season == 2021:  # if 2021, remove ivy league because they cancelled their season in 2021
    df_active_teams = df_active_teams.loc[
        ~df_active_teams['School'].isin(['Princeton', 'Harvard', 'Yale', 'Pennsylvania', 'Brown', 'Columbia', 'Cornell', 'Dartmouth']),
        :
    ].reset_index(drop=True)

df_active_teams
# Out:
#       Rk             School             City, State  From    To  Yrs     G  \
# 0      1  Abilene Christian          Abilene, Texas  1971  2025   15   452
# 1      2          Air Force  USAF Academy, Colorado  1958  2025   68  1873
# 2      3              Akron             Akron, Ohio  1902  2025   74  1748
# 3      4            Alabama     Tuscaloosa, Alabama  1913  2025  112  2926
# 4      5        Alabama A&M         Normal, Alabama  2000  2025   26   752
# ..   ...                ...                     ...   ...   ...  ...   ...
# 342  489       Wright State            Dayton, Ohio  1988  2025   38  1160
# 343  490            Wyoming        Laramie, Wyoming  1905  2025  120  2910
# 344  491             Xavier        Cincinnati, Ohio  1920  2025  104  2727
# 345  492               Yale  New Haven, Connecticut  1896  2025  129  3111
# 346  493   Youngstown State        Youngstown, Ohio  1948  2025   45  1323
#
#         W     L  W-L%     SRS     SOS  AP CREG CTRN NCAA FF NC
# 0     241   211  .533   -7.59   -5.36   0    0    2    2  0  0
# 1     797  1076  .426   -2.86    1.37   0    1    0    4  0  0
# 2    1051   697  .601    0.07   -1.60   0    9    6    6  0  0
# 3    1817  1108  .621    8.18    5.06  18   10    9   25  1  0
# 4     287   465  .382  -16.72  -11.01   0    1    1    1  0  0
# ..    ...   ...   ...     ...     ...  ..  ...  ...  ... .. ..
# 342   646   514  .557   -1.41   -2.60   0    4    4    4  0  0
# 343  1622  1288  .557    2.69    2.76   4   21    3   16  1  1
# 344  1631  1096  .598    6.20    4.05  13   18    9   29  0  0
# 345  1585  1524  .510   -5.81   -4.43   1   16    3    7  0  0
# 346   549   774  .415   -7.88   -3.56   0    1    0    0  0  0
#
# [347 rows x 18 columns]

# %% [markdown]
# Heads up that there is an issue with 2023. Some games from UAB and Florida international have either more or less than 5 starters listed. I manually removed those games from this analysis.

# %%
from datetime import datetime

cutoff_dates = {
    2008: datetime(2008, 3, 21),
    2009: datetime(2009, 3, 20),
    2010: datetime(2010, 3, 19),
    2011: datetime(2011, 3, 18),
    2012: datetime(2012, 3, 16),
    2013: datetime(2013, 3, 22),
    2014: datetime(2014, 3, 21),
    2015: datetime(2015, 3, 19),
    2016: datetime(2016, 3, 17),
    2017: datetime(2017, 3, 16),
    2018: datetime(2018, 3, 15),
    2019: datetime(2019, 3, 21),
    2020: datetime(2020, 3, 13),  # cancelled
    2021: datetime(2021, 3, 24),
    2022: datetime(2022, 3, 17),
    2023: datetime(2023, 3, 16),
    2024: datetime(2024, 3, 21),
    2025: datetime(2025, 3, 20),
}

cutoff_dates[season]
# Out:
# datetime.datetime(2012, 3, 16, 0, 0)

# %% [markdown]
# Get school names used in Sports Reference URL

# %%
df_active_teams['URL School'] = df_active_teams['School']

# hard code some schools that cause issues
df_active_teams.loc[df_active_teams['School'] == 'Bowling Green', 'URL School'] = 'Bowling Green State'
df_active_teams.loc[df_active_teams['School'] == 'BYU', 'URL School'] = 'Brigham Young'
df_active_teams.loc[df_active_teams['School'] == 'Louisiana', 'URL School'] = 'Louisiana Lafayette'
df_active_teams.loc[df_active_teams['School'] == 'LSU', 'URL School'] = 'Louisiana State'
df_active_teams.loc[df_active_teams['School'] == 'Ole Miss', 'URL School'] = 'Mississippi'
df_active_teams.loc[df_active_teams['School'] == 'Pitt', 'URL School'] = 'Pittsburgh'
df_active_teams.loc[df_active_teams['School'] == 'SMU', 'URL School'] = 'Southern Methodist'
df_active_teams.loc[df_active_teams['School'] == 'UAB', 'URL School'] = 'Alabama Birmingham'
df_active_teams.loc[df_active_teams['School'] == 'UCF', 'URL School'] = 'Central Florida'
df_active_teams.loc[df_active_teams['School'] == 'USC', 'URL School'] = 'Southern California'
df_active_teams.loc[df_active_teams['School'] == 'UTEP', 'URL School'] = 'Texas El Paso'
df_active_teams.loc[df_active_teams['School'] == 'UTSA', 'URL School'] = 'Texas San Antonio'
df_active_teams.loc[df_active_teams['School'] == 'Sam Houston', 'URL School'] = 'Sam Houston State'
df_active_teams.loc[df_active_teams['School'] == 'Houston Christian', 'URL School'] = 'Houston Baptist'
df_active_teams.loc[df_active_teams['School'] == 'Kansas City', 'URL School'] = 'Missouri Kansas City'
df_active_teams.loc[df_active_teams['School'] == 'Little Rock', 'URL School'] = 'Arkansas Little Rock'
df_active_teams.loc[df_active_teams['School'] == 'NC State', 'URL School'] = 'North Carolina State'
df_active_teams.loc[df_active_teams['School'] == 'Omaha', 'URL School'] = 'Nebraska Omaha'
df_active_teams.loc[df_active_teams['School'] == 'Purdue Fort Wayne', 'URL School'] = 'IPFW'
df_active_teams.loc[df_active_teams['School'] == 'TCU', 'URL School'] = 'Texas Christian'
df_active_teams.loc[df_active_teams['School'] == 'Texas-Rio Grande Valley', 'URL School'] = 'Texas Pan American'
df_active_teams.loc[df_active_teams['School'] == 'The Citadel', 'URL School'] = 'Citadel'
df_active_teams.loc[df_active_teams['School'] == 'Utah Tech', 'URL School'] = 'Dixie State'
df_active_teams.loc[df_active_teams['School'] == 'St. Thomas', 'URL School'] = 'St. Thomas MN'
df_active_teams.loc[df_active_teams['School'] == 'UC Berkley', 'URL School'] = 'California'
df_active_teams.loc[df_active_teams['School'] == 'UT Arlington', 'URL School'] = 'Texas Arlington'
df_active_teams.loc[df_active_teams['School'] == 'FDU', 'URL School'] = 'Fairleigh Dickinson'
df_active_teams.loc[df_active_teams['School'] == 'Hartford Hawks', 'URL School'] = 'Hartford'
df_active_teams.loc[df_active_teams['School'] == 'Savannah State Tigers', 'URL School'] = 'Savannah State'
df_active_teams.loc[df_active_teams['School'] == 'St. Francis (NY) Terriers', 'URL School'] = 'St. Francis (NY)'
df_active_teams.loc[df_active_teams['School'] == 'East Texas A&M', 'URL School'] = 'Texas A&M Commerce'
df_active_teams.loc[df_active_teams['School'] == 'IU Indy', 'URL School'] = 'IUPUI'

df_active_teams['URL School'] = df_active_teams['URL School'].str.replace(r'^UC\s', 'California ', regex=True)
df_active_teams['URL School'] = df_active_teams['URL School'].str.replace(r'^UNC\s', 'North Carolina ', regex=True)

# %%
urls = (
    'https://www.sports-reference.com/cbb/schools/' +
    df_active_teams['URL School'].str.replace(' ', '-', regex=False).str.replace('[)(&.\']', '', regex=True).str.replace('--', '-', regex=False).str.lower() +
    '/women/' + str(season) +
    '-starters.html'
)

urls
# Out:
# 0      https://www.sports-reference.com/cbb/schools/a...
# 1      https://www.sports-reference.com/cbb/schools/a...
# 2      https://www.sports-reference.com/cbb/schools/a...
# 3      https://www.sports-reference.com/cbb/schools/a...
# 4      https://www.sports-reference.com/cbb/schools/a...
#                              ...
# 342    https://www.sports-reference.com/cbb/schools/w...
# 343    https://www.sports-reference.com/cbb/schools/w...
# 344    https://www.sports-reference.com/cbb/schools/x...
# 345    https://www.sports-reference.com/cbb/schools/y...
# 346    https://www.sports-reference.com/cbb/schools/y...
# Name: URL School, Length: 347, dtype: object

# %%
from urllib.error import HTTPError
from tqdm.notebook import tqdm

problems = []

l = []
loop = tqdm(
    np.array((df_active_teams['School'], urls)).transpose(),  # get both school and url into loop iteration
    bar_format='{bar}{percentage:3.0f}%{r_bar}   {desc}'  # make the description not affect bar location
)

for (school, url) in loop:
  try:
    loop.set_description(f'{school}')
    # print(f'{i:03d}: {url}')
    df_team_season = pd.read_html(url)[0]  # starters should be initial table on site
    time.sleep(2)
    
    df_team_season.insert(4, 'Team', school)
    l.append(df_team_season)
  except HTTPError as e:
    if e.code == 404:
      print(f'{url} | {e}')
      time.sleep(2)
    else:
      print(f'{url} | {e}')
      break

df = pd.concat(l, ignore_index=True)

df
# Out:
#             0%| 0/347 [00:00<?, ?it/s]
# https://www.sports-reference.com/cbb/schools/abilene-christian/women/2012-starters.html | HTTP Error 404: Not Found
# https://www.sports-reference.com/cbb/schools/longwood/women/2012-starters.html | HTTP Error 404: Not Found
# https://www.sports-reference.com/cbb/schools/massachusetts-lowell/women/2012-starters.html | HTTP Error 404: Not Found
# https://www.sports-reference.com/cbb/schools/citadel/women/2012-starters.html | HTTP Error 404: Not Found
# https://www.sports-reference.com/cbb/schools/virginia-military-institute/women/2012-starters.html | HTTP Error 404: Not Found
#         G               Date  Unnamed: 2 Unnamed: 3              Team  \
# 0       1  Fri, Nov 11, 2011         NaN  Box Score         Air Force
# 1       2  Sun, Nov 13, 2011         NaN  Box Score         Air Force
# 2       3  Thu, Nov 17, 2011         NaN  Box Score         Air Force
# 3       4  Sat, Nov 19, 2011         NaN  Box Score         Air Force
# 4       5  Mon, Nov 21, 2011         NaN  Box Score         Air Force
# ...    ..                ...         ...        ...               ...
# 10694  26  Sat, Feb 18, 2012         NaN  Box Score  Youngstown State
# 10695  27  Thu, Feb 23, 2012         NaN  Box Score  Youngstown State
# 10696  28  Sat, Feb 25, 2012         NaN  Box Score  Youngstown State
# 10697  29   Sat, Mar 3, 2012         NaN  Box Score  Youngstown State
# 10698  30   Mon, Mar 5, 2012         NaN  Box Score  Youngstown State
#
#       Unnamed: 4          Opponent Unnamed: 6   OT  Tm  Opp   W   L  \
# 0              @          Lipscomb          W  NaN  68   59   1   0
# 1              @  Tennessee-Martin          L  NaN  60   84   1   1
# 2            NaN            Denver          L  NaN  52   54   1   2
# 3              @    Texas Southern          W  NaN  64   54   2   2
# 4              @       Texas State          W  NaN  77   69   3   2
# ...          ...               ...        ...  ...  ..  ...  ..  ..
# 10694        NaN         Green Bay          L   OT  72   77  10  16
# 10695          @      Wright State          L  NaN  62   84  10  17
# 10696          @     Detroit Mercy          L  NaN  64   67  10  18
# 10697          @   Cleveland State          L  NaN  69   79  10  19
# 10698          @   Cleveland State          L  NaN  56   59  10  20
#
#                                              Unnamed: 12
# 0      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 1      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 2      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 3      D. James · A. Leipprandt · C. Medina · M. O'Ne...
# 4      D. James · A. Leipprandt · M. O'Neil · D. Sorr...
# ...                                                  ...
# 10694  B. Brown · K. Fickiesen · T. Jones · K. Middle...
# 10695  B. Brown · K. Fickiesen · T. Jones · K. Middle...
# 10696  B. Brown · K. Fickiesen · L. Hornberger · K. M...
# 10697  B. Brown · K. Fickiesen · K. Middlebrooks · H....
# 10698  B. Brown · K. Fickiesen · K. Middlebrooks · H....
#
# [10699 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10699 entries, 0 to 10698
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   G            10699 non-null  int64
#  1   Date         10699 non-null  object
#  2   Unnamed: 2   0 non-null      float64
#  3   Unnamed: 3   10697 non-null  object
#  4   Team         10699 non-null  object
#  5   Unnamed: 4   5309 non-null   object
#  6   Opponent     10699 non-null  object
#  7   Unnamed: 6   10699 non-null  object
#  8   OT           448 non-null    object
#  9   Tm           10699 non-null  int64
#  10  Opp          10699 non-null  int64
#  11  W            10699 non-null  int64
#  12  L            10699 non-null  int64
#  13  Unnamed: 12  10696 non-null  object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Data Setup

# %%
temp = df.copy()

# %%
df = temp.copy()

# %% [markdown]
# Fix column names and drop useless columns

# %%
df.drop(columns=['G', 'Unnamed: 2', 'Unnamed: 3', 'W', 'L'], inplace=True)

df.columns = ['Date', 'Team', 'Location', 'Opponent', 'Result', 'Overtime', 'Team Score', 'Opponent Score', 'Starters']

df
# Out:
#                     Date              Team Location          Opponent Result  \
# 0      Fri, Nov 11, 2011         Air Force        @          Lipscomb      W
# 1      Sun, Nov 13, 2011         Air Force        @  Tennessee-Martin      L
# 2      Thu, Nov 17, 2011         Air Force      NaN            Denver      L
# 3      Sat, Nov 19, 2011         Air Force        @    Texas Southern      W
# 4      Mon, Nov 21, 2011         Air Force        @       Texas State      W
# ...                  ...               ...      ...               ...    ...
# 10694  Sat, Feb 18, 2012  Youngstown State      NaN         Green Bay      L
# 10695  Thu, Feb 23, 2012  Youngstown State        @      Wright State      L
# 10696  Sat, Feb 25, 2012  Youngstown State        @     Detroit Mercy      L
# 10697   Sat, Mar 3, 2012  Youngstown State        @   Cleveland State      L
# 10698   Mon, Mar 5, 2012  Youngstown State        @   Cleveland State      L
#
#       Overtime  Team Score  Opponent Score  \
# 0          NaN          68              59
# 1          NaN          60              84
# 2          NaN          52              54
# 3          NaN          64              54
# 4          NaN          77              69
# ...        ...         ...             ...
# 10694       OT          72              77
# 10695      NaN          62              84
# 10696      NaN          64              67
# 10697      NaN          69              79
# 10698      NaN          56              59
#
#                                                 Starters
# 0      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 1      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 2      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 3      D. James · A. Leipprandt · C. Medina · M. O'Ne...
# 4      D. James · A. Leipprandt · M. O'Neil · D. Sorr...
# ...                                                  ...
# 10694  B. Brown · K. Fickiesen · T. Jones · K. Middle...
# 10695  B. Brown · K. Fickiesen · T. Jones · K. Middle...
# 10696  B. Brown · K. Fickiesen · L. Hornberger · K. M...
# 10697  B. Brown · K. Fickiesen · K. Middlebrooks · H....
# 10698  B. Brown · K. Fickiesen · K. Middlebrooks · H....
#
# [10699 rows x 9 columns]

# %%
# remove games that have not been played
df = df.loc[(df['Result'].notna()) & (df['Result'] != 'W/L'), :].reset_index(drop=True)

# get overtime info
df['Overtime'] = df['Overtime'].notna().astype('int8')

# reformat result column
df['Result'] = df['Result'].str[:1].map({'W': 1, 'L': -1}).astype('int8')

# remove games with non-D1 opponents
df = df.loc[df['Opponent'].isin(df['Team']), :].reset_index(drop=True)

# remove games where starters are not listed
df = df.loc[df['Starters'].notna(), :].reset_index(drop=True)

df
# Out:
#                     Date              Team Location          Opponent  Result  \
# 0      Fri, Nov 11, 2011         Air Force        @          Lipscomb       1
# 1      Sun, Nov 13, 2011         Air Force        @  Tennessee-Martin      -1
# 2      Thu, Nov 17, 2011         Air Force      NaN            Denver      -1
# 3      Sat, Nov 19, 2011         Air Force        @    Texas Southern       1
# 4      Mon, Nov 21, 2011         Air Force        @       Texas State       1
# ...                  ...               ...      ...               ...     ...
# 10365  Sat, Feb 18, 2012  Youngstown State      NaN         Green Bay      -1
# 10366  Thu, Feb 23, 2012  Youngstown State        @      Wright State      -1
# 10367  Sat, Feb 25, 2012  Youngstown State        @     Detroit Mercy      -1
# 10368   Sat, Mar 3, 2012  Youngstown State        @   Cleveland State      -1
# 10369   Mon, Mar 5, 2012  Youngstown State        @   Cleveland State      -1
#
#        Overtime  Team Score  Opponent Score  \
# 0             0          68              59
# 1             0          60              84
# 2             0          52              54
# 3             0          64              54
# 4             0          77              69
# ...         ...         ...             ...
# 10365         1          72              77
# 10366         0          62              84
# 10367         0          64              67
# 10368         0          69              79
# 10369         0          56              59
#
#                                                 Starters
# 0      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 1      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 2      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 3      D. James · A. Leipprandt · C. Medina · M. O'Ne...
# 4      D. James · A. Leipprandt · M. O'Neil · D. Sorr...
# ...                                                  ...
# 10365  B. Brown · K. Fickiesen · T. Jones · K. Middle...
# 10366  B. Brown · K. Fickiesen · T. Jones · K. Middle...
# 10367  B. Brown · K. Fickiesen · L. Hornberger · K. M...
# 10368  B. Brown · K. Fickiesen · K. Middlebrooks · H....
# 10369  B. Brown · K. Fickiesen · K. Middlebrooks · H....
#
# [10370 rows x 9 columns]

# %% [markdown]
# Reformat location column for home/neutral/away

# %%
df['Location'] = df['Location'].map({np.NaN: 1, 'N': 0, '@': -1}).astype('int8')

df['Location']
# Out:
# 0       -1
# 1       -1
# 2        1
# 3       -1
# 4       -1
#         ..
# 10365    1
# 10366   -1
# 10367   -1
# 10368   -1
# 10369   -1
# Name: Location, Length: 10370, dtype: int8

# %% [markdown]
# Other general fixes

# %%
# fix dates
df['Date'] = pd.to_datetime(df['Date'])

# specify before and after NCAA tournament
df.insert(df.columns.get_loc('Date') + 1, 'NCAA Tournament', (df['Date'] > cutoff_dates[season]).astype(int))

# for starters, we only look at pre-tournament games as we are not looking at past years
df = df.loc[df['NCAA Tournament'] == 0, :].reset_index(drop=True)

# fix column types
df.loc[:, df.columns.str.contains('Team ', regex=False)] = df.loc[:, df.columns.str.contains('Team ', regex=False)].astype('float64')
df.loc[:, df.columns.str.contains('Opponent ', regex=False)] = df.loc[:, df.columns.str.contains('Opponent ', regex=False)].astype('float64')

df
# Out:
#             Date  NCAA Tournament              Team  Location  \
# 0     2011-11-11                0         Air Force        -1
# 1     2011-11-13                0         Air Force        -1
# 2     2011-11-17                0         Air Force         1
# 3     2011-11-19                0         Air Force        -1
# 4     2011-11-21                0         Air Force        -1
# ...          ...              ...               ...       ...
# 10163 2012-02-18                0  Youngstown State         1
# 10164 2012-02-23                0  Youngstown State        -1
# 10165 2012-02-25                0  Youngstown State        -1
# 10166 2012-03-03                0  Youngstown State        -1
# 10167 2012-03-05                0  Youngstown State        -1
#
#                Opponent  Result  Overtime  Team Score  Opponent Score  \
# 0              Lipscomb       1         0          68              59
# 1      Tennessee-Martin      -1         0          60              84
# 2                Denver      -1         0          52              54
# 3        Texas Southern       1         0          64              54
# 4           Texas State       1         0          77              69
# ...                 ...     ...       ...         ...             ...
# 10163         Green Bay      -1         1          72              77
# 10164      Wright State      -1         0          62              84
# 10165     Detroit Mercy      -1         0          64              67
# 10166   Cleveland State      -1         0          69              79
# 10167   Cleveland State      -1         0          56              59
#
#                                                 Starters
# 0      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 1      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 2      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 3      D. James · A. Leipprandt · C. Medina · M. O'Ne...
# 4      D. James · A. Leipprandt · M. O'Neil · D. Sorr...
# ...                                                  ...
# 10163  B. Brown · K. Fickiesen · T. Jones · K. Middle...
# 10164  B. Brown · K. Fickiesen · T. Jones · K. Middle...
# 10165  B. Brown · K. Fickiesen · L. Hornberger · K. M...
# 10166  B. Brown · K. Fickiesen · K. Middlebrooks · H....
# 10167  B. Brown · K. Fickiesen · K. Middlebrooks · H....
#
# [10168 rows x 10 columns]

# %% [markdown]
# Get opponent starters

# %%
# create a pseudo game ID that can be looked at from opponent's perspective to get opposing starters
key_to_starters = dict(zip(
    df['Date'].astype(str) + ' ' + df['Team'] + ' ' + df['Opponent'] + ' ' + df['Team Score'].astype(str) + ' ' + df['Opponent Score'].astype(str),
    df['Starters']
))

df['Opponent Starters'] = (df['Date'].astype(str) + ' ' + df['Opponent'] + ' ' + df['Team'] + ' ' + df['Opponent Score'].astype(str) + ' ' + df['Team Score'].astype(str)).map(key_to_starters)

df
# Out:
#             Date  NCAA Tournament              Team  Location  \
# 0     2011-11-11                0         Air Force        -1
# 1     2011-11-13                0         Air Force        -1
# 2     2011-11-17                0         Air Force         1
# 3     2011-11-19                0         Air Force        -1
# 4     2011-11-21                0         Air Force        -1
# ...          ...              ...               ...       ...
# 10163 2012-02-18                0  Youngstown State         1
# 10164 2012-02-23                0  Youngstown State        -1
# 10165 2012-02-25                0  Youngstown State        -1
# 10166 2012-03-03                0  Youngstown State        -1
# 10167 2012-03-05                0  Youngstown State        -1
#
#                Opponent  Result  Overtime  Team Score  Opponent Score  \
# 0              Lipscomb       1         0          68              59
# 1      Tennessee-Martin      -1         0          60              84
# 2                Denver      -1         0          52              54
# 3        Texas Southern       1         0          64              54
# 4           Texas State       1         0          77              69
# ...                 ...     ...       ...         ...             ...
# 10163         Green Bay      -1         1          72              77
# 10164      Wright State      -1         0          62              84
# 10165     Detroit Mercy      -1         0          64              67
# 10166   Cleveland State      -1         0          69              79
# 10167   Cleveland State      -1         0          56              59
#
#                                                 Starters  \
# 0      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 1      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 2      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 3      D. James · A. Leipprandt · C. Medina · M. O'Ne...
# 4      D. James · A. Leipprandt · M. O'Neil · D. Sorr...
# ...                                                  ...
# 10163  B. Brown · K. Fickiesen · T. Jones · K. Middle...
# 10164  B. Brown · K. Fickiesen · T. Jones · K. Middle...
# 10165  B. Brown · K. Fickiesen · L. Hornberger · K. M...
# 10166  B. Brown · K. Fickiesen · K. Middlebrooks · H....
# 10167  B. Brown · K. Fickiesen · K. Middlebrooks · H....
#
#                                        Opponent Starters
# 0      A. Bowers · M. Faulkner · H. Phillips · O. Smi...
# 1      H. Butler · S. Crawford · J. Haislip · T. Hall...
# 2      M. Michel · K. Murdoch · Q. Noonan · M. Shell ...
# 3      C. Anyiam · G. Fleming · A. Hall · J. McQueen ...
# 4      D. Clinch · A. Ezeh · D. Ford · I. Johnson · V...
# ...                                                  ...
# 10163  L. Bauer · M. Lukan · H. Quilling · A. Ritchie...
# 10164  C. Boyd · K. Demmings · M. Fox · K. Lamotte · ...
# 10165  L. Allen · S. Brown · M. Hatter · J. Jones · S...
# 10166  J. Adams · C. Coleman · T. Keane · H. King · S...
# 10167  J. Adams · C. Coleman · T. Keane · H. King · S...
#
# [10168 rows x 11 columns]

# %%
df.loc[df['Opponent Starters'].isna(), :]
# Out:
#            Date  NCAA Tournament                       Team  Location  \
# 3075 2011-11-11                0             Hartford Hawks         1
# 3076 2011-11-13                0             Hartford Hawks         1
# 3077 2011-11-17                0             Hartford Hawks        -1
# 3078 2011-11-22                0             Hartford Hawks         1
# 3079 2011-11-25                0             Hartford Hawks         1
# ...         ...              ...                        ...       ...
# 8153 2012-02-15                0  St. Francis (NY) Terriers         1
# 8154 2012-02-18                0  St. Francis (NY) Terriers         1
# 8155 2012-02-20                0  St. Francis (NY) Terriers        -1
# 8156 2012-02-25                0  St. Francis (NY) Terriers        -1
# 8157 2012-02-27                0  St. Francis (NY) Terriers        -1
#
#                        Opponent  Result  Overtime  Team Score  Opponent Score  \
# 3075                  Manhattan       1         0          64              45
# 3076     Long Island University       1         0          54              45
# 3077                 Notre Dame      -1         0          43              98
# 3078  Central Connecticut State       1         0          65              56
# 3079                        TCU       1         0          64              60
# ...                         ...     ...       ...         ...             ...
# 8153     Long Island University      -1         0          53              60
# 8154               Sacred Heart      -1         0          53              57
# 8155                 Quinnipiac      -1         0          41              64
# 8156                        FDU       1         0          62              47
# 8157                   Monmouth      -1         0          61              66
#
#                                                Starters Opponent Starters
# 3075  A. Bepko · R. Doherty · D. Elliott · A. Hall ·...               NaN
# 3076  A. Bepko · R. Doherty · D. Elliott · A. Hall ·...               NaN
# 3077  A. Bepko · R. Doherty · D. Elliott · A. Hall ·...               NaN
# 3078  A. Bepko · R. Doherty · D. Elliott · A. Hall ·...               NaN
# 3079  A. Bepko · R. Doherty · D. Elliott · A. Hall ·...               NaN
# ...                                                 ...               ...
# 8153  S. Benedetti · K. Fox · J. Kaufman · J. Robins...               NaN
# 8154  S. Benedetti · K. Fox · J. Kaufman · J. Robins...               NaN
# 8155  S. Benedetti · K. Fox · J. Kaufman · J. Robins...               NaN
# 8156  S. Benedetti · T. Dunson · J. Kaufman · J. Rob...               NaN
# 8157  S. Benedetti · K. Fox · J. Robinson · K. Snauw...               NaN
#
# [88 rows x 11 columns]

# %%
df = df.loc[df['Opponent Starters'].notna(), :].reset_index(drop=True)

df
# Out:
#             Date  NCAA Tournament              Team  Location  \
# 0     2011-11-11                0         Air Force        -1
# 1     2011-11-13                0         Air Force        -1
# 2     2011-11-17                0         Air Force         1
# 3     2011-11-19                0         Air Force        -1
# 4     2011-11-21                0         Air Force        -1
# ...          ...              ...               ...       ...
# 10075 2012-02-18                0  Youngstown State         1
# 10076 2012-02-23                0  Youngstown State        -1
# 10077 2012-02-25                0  Youngstown State        -1
# 10078 2012-03-03                0  Youngstown State        -1
# 10079 2012-03-05                0  Youngstown State        -1
#
#                Opponent  Result  Overtime  Team Score  Opponent Score  \
# 0              Lipscomb       1         0          68              59
# 1      Tennessee-Martin      -1         0          60              84
# 2                Denver      -1         0          52              54
# 3        Texas Southern       1         0          64              54
# 4           Texas State       1         0          77              69
# ...                 ...     ...       ...         ...             ...
# 10075         Green Bay      -1         1          72              77
# 10076      Wright State      -1         0          62              84
# 10077     Detroit Mercy      -1         0          64              67
# 10078   Cleveland State      -1         0          69              79
# 10079   Cleveland State      -1         0          56              59
#
#                                                 Starters  \
# 0      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 1      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 2      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...
# 3      D. James · A. Leipprandt · C. Medina · M. O'Ne...
# 4      D. James · A. Leipprandt · M. O'Neil · D. Sorr...
# ...                                                  ...
# 10075  B. Brown · K. Fickiesen · T. Jones · K. Middle...
# 10076  B. Brown · K. Fickiesen · T. Jones · K. Middle...
# 10077  B. Brown · K. Fickiesen · L. Hornberger · K. M...
# 10078  B. Brown · K. Fickiesen · K. Middlebrooks · H....
# 10079  B. Brown · K. Fickiesen · K. Middlebrooks · H....
#
#                                        Opponent Starters
# 0      A. Bowers · M. Faulkner · H. Phillips · O. Smi...
# 1      H. Butler · S. Crawford · J. Haislip · T. Hall...
# 2      M. Michel · K. Murdoch · Q. Noonan · M. Shell ...
# 3      C. Anyiam · G. Fleming · A. Hall · J. McQueen ...
# 4      D. Clinch · A. Ezeh · D. Ford · I. Johnson · V...
# ...                                                  ...
# 10075  L. Bauer · M. Lukan · H. Quilling · A. Ritchie...
# 10076  C. Boyd · K. Demmings · M. Fox · K. Lamotte · ...
# 10077  L. Allen · S. Brown · M. Hatter · J. Jones · S...
# 10078  J. Adams · C. Coleman · T. Keane · H. King · S...
# 10079  J. Adams · C. Coleman · T. Keane · H. King · S...
#
# [10080 rows x 11 columns]

# %% [markdown]
# Split starters into separate columns

# %%
# rename starters column
df.rename(columns={'Starters': 'Team Starters'}, inplace=True)

df[[f'Team Starter {i}' for i in range(1, 6)]] = df['Team Starters'].str.split(r'\xa0· | \·', regex=True, expand=True)

for i in range(1, 6):
    df[f'Team Starter {i}'] = df['Team'] + ' ' + df[f'Team Starter {i}']

df[[f'Opponent Starter {i}' for i in range(1, 6)]] = df['Opponent Starters'].str.split(r'\xa0· | \·', regex=True, expand=True)

for i in range(1, 6):
    df[f'Opponent Starter {i}'] = df['Opponent'] + ' ' + df[f'Opponent Starter {i}']

df
# Out:
#             Date  NCAA Tournament              Team  Location  \
# 0     2011-11-11                0         Air Force        -1
# 1     2011-11-13                0         Air Force        -1
# 2     2011-11-17                0         Air Force         1
# 3     2011-11-19                0         Air Force        -1
# 4     2011-11-21                0         Air Force        -1
# ...          ...              ...               ...       ...
# 10075 2012-02-18                0  Youngstown State         1
# 10076 2012-02-23                0  Youngstown State        -1
# 10077 2012-02-25                0  Youngstown State        -1
# 10078 2012-03-03                0  Youngstown State        -1
# 10079 2012-03-05                0  Youngstown State        -1
#
#                Opponent  Result  Overtime  Team Score  Opponent Score  \
# 0              Lipscomb       1         0          68              59
# 1      Tennessee-Martin      -1         0          60              84
# 2                Denver      -1         0          52              54
# 3        Texas Southern       1         0          64              54
# 4           Texas State       1         0          77              69
# ...                 ...     ...       ...         ...             ...
# 10075         Green Bay      -1         1          72              77
# 10076      Wright State      -1         0          62              84
# 10077     Detroit Mercy      -1         0          64              67
# 10078   Cleveland State      -1         0          69              79
# 10079   Cleveland State      -1         0          56              59
#
#                                            Team Starters  ...  \
# 0      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...  ...
# 1      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...  ...
# 2      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...  ...
# 3      D. James · A. Leipprandt · C. Medina · M. O'Ne...  ...
# 4      D. James · A. Leipprandt · M. O'Neil · D. Sorr...  ...
# ...                                                  ...  ...
# 10075  B. Brown · K. Fickiesen · T. Jones · K. Middle...  ...
# 10076  B. Brown · K. Fickiesen · T. Jones · K. Middle...  ...
# 10077  B. Brown · K. Fickiesen · L. Hornberger · K. M...  ...
# 10078  B. Brown · K. Fickiesen · K. Middlebrooks · H....  ...
# 10079  B. Brown · K. Fickiesen · K. Middlebrooks · H....  ...
#
#                   Team Starter 1                 Team Starter 2  \
# 0            Air Force K. Hilbig        Air Force A. Leipprandt
# 1            Air Force K. Hilbig        Air Force A. Leipprandt
# 2            Air Force K. Hilbig        Air Force A. Leipprandt
# 3             Air Force D. James        Air Force A. Leipprandt
# 4             Air Force D. James        Air Force A. Leipprandt
# ...                          ...                            ...
# 10075  Youngstown State B. Brown  Youngstown State K. Fickiesen
# 10076  Youngstown State B. Brown  Youngstown State K. Fickiesen
# 10077  Youngstown State B. Brown  Youngstown State K. Fickiesen
# 10078  Youngstown State B. Brown  Youngstown State K. Fickiesen
# 10079  Youngstown State B. Brown  Youngstown State K. Fickiesen
#
#                          Team Starter 3                    Team Starter 4  \
# 0                   Air Force C. Medina          Air Force J. Satterfield
# 1                   Air Force C. Medina          Air Force J. Satterfield
# 2                   Air Force C. Medina          Air Force J. Satterfield
# 3                   Air Force C. Medina               Air Force M. O'Neil
# 4                   Air Force M. O'Neil              Air Force D. Sorrera
# ...                                 ...                               ...
# 10075         Youngstown State T. Jones  Youngstown State K. Middlebrooks
# 10076         Youngstown State T. Jones  Youngstown State K. Middlebrooks
# 10077    Youngstown State L. Hornberger  Youngstown State K. Middlebrooks
# 10078  Youngstown State K. Middlebrooks      Youngstown State H. Schlegel
# 10079  Youngstown State K. Middlebrooks      Youngstown State H. Schlegel
#
#                      Team Starter 5          Opponent Starter 1  \
# 0             Air Force C. Thompson          Lipscomb A. Bowers
# 1             Air Force C. Thompson  Tennessee-Martin H. Butler
# 2             Air Force C. Thompson            Denver M. Michel
# 3             Air Force C. Thompson    Texas Southern C. Anyiam
# 4             Air Force C. Thompson       Texas State D. Clinch
# ...                             ...                         ...
# 10075    Youngstown State M. Nortey          Green Bay L. Bauer
# 10076    Youngstown State M. Nortey        Wright State C. Boyd
# 10077  Youngstown State H. Schlegel      Detroit Mercy L. Allen
# 10078  Youngstown State M. Touvelle    Cleveland State J. Adams
# 10079  Youngstown State M. Thompson    Cleveland State J. Adams
#
#                  Opponent Starter 2           Opponent Starter 3  \
# 0              Lipscomb M. Faulkner         Lipscomb H. Phillips
# 1      Tennessee-Martin S. Crawford  Tennessee-Martin J. Haislip
# 2                 Denver K. Murdoch             Denver Q. Noonan
# 3         Texas Southern G. Fleming       Texas Southern A. Hall
# 4               Texas State A. Ezeh          Texas State D. Ford
# ...                             ...                          ...
# 10075            Green Bay M. Lukan        Green Bay H. Quilling
# 10076      Wright State K. Demmings          Wright State M. Fox
# 10077        Detroit Mercy S. Brown      Detroit Mercy M. Hatter
# 10078    Cleveland State C. Coleman     Cleveland State T. Keane
# 10079    Cleveland State C. Coleman     Cleveland State T. Keane
#
#               Opponent Starter 4           Opponent Starter 5
# 0              Lipscomb O. Smith      Lipscomb E. Thornsberry
# 1       Tennessee-Martin T. Hall  Tennessee-Martin J. Newsome
# 2                Denver M. Shell              Denver E. Smith
# 3      Texas Southern J. McQueen       Texas Southern K. West
# 4         Texas State I. Johnson          Texas State V. Kalu
# ...                          ...                          ...
# 10075       Green Bay A. Ritchie           Green Bay J. Wojta
# 10076    Wright State K. Lamotte     Wright State S. Sandifer
# 10077     Detroit Mercy J. Jones     Detroit Mercy S. Shearer
# 10078    Cleveland State H. King    Cleveland State S. Winton
# 10079    Cleveland State H. King    Cleveland State S. Winton
#
# [10080 rows x 21 columns]

# %% [markdown]
# Set up adjusted Score Differential

# %%
blowout_threshold = 18  # adjusted score differential will only account up to this score difference

df['Score Differential'] = df['Team Score'] - df['Opponent Score']

df['Adjusted Score Differential'] = df['Score Differential'].abs()

df.loc[df['Adjusted Score Differential'] > blowout_threshold, 'Adjusted Score Differential'] = blowout_threshold

df['Adjusted Score Differential'] = df['Adjusted Score Differential']**(np.log(1.5)/np.log(blowout_threshold))

df
# Out:
#             Date  NCAA Tournament              Team  Location  \
# 0     2011-11-11                0         Air Force        -1
# 1     2011-11-13                0         Air Force        -1
# 2     2011-11-17                0         Air Force         1
# 3     2011-11-19                0         Air Force        -1
# 4     2011-11-21                0         Air Force        -1
# ...          ...              ...               ...       ...
# 10075 2012-02-18                0  Youngstown State         1
# 10076 2012-02-23                0  Youngstown State        -1
# 10077 2012-02-25                0  Youngstown State        -1
# 10078 2012-03-03                0  Youngstown State        -1
# 10079 2012-03-05                0  Youngstown State        -1
#
#                Opponent  Result  Overtime  Team Score  Opponent Score  \
# 0              Lipscomb       1         0          68              59
# 1      Tennessee-Martin      -1         0          60              84
# 2                Denver      -1         0          52              54
# 3        Texas Southern       1         0          64              54
# 4           Texas State       1         0          77              69
# ...                 ...     ...       ...         ...             ...
# 10075         Green Bay      -1         1          72              77
# 10076      Wright State      -1         0          62              84
# 10077     Detroit Mercy      -1         0          64              67
# 10078   Cleveland State      -1         0          69              79
# 10079   Cleveland State      -1         0          56              59
#
#                                            Team Starters  ...  \
# 0      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...  ...
# 1      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...  ...
# 2      K. Hilbig · A. Leipprandt · C. Medina · J. Sat...  ...
# 3      D. James · A. Leipprandt · C. Medina · M. O'Ne...  ...
# 4      D. James · A. Leipprandt · M. O'Neil · D. Sorr...  ...
# ...                                                  ...  ...
# 10075  B. Brown · K. Fickiesen · T. Jones · K. Middle...  ...
# 10076  B. Brown · K. Fickiesen · T. Jones · K. Middle...  ...
# 10077  B. Brown · K. Fickiesen · L. Hornberger · K. M...  ...
# 10078  B. Brown · K. Fickiesen · K. Middlebrooks · H....  ...
# 10079  B. Brown · K. Fickiesen · K. Middlebrooks · H....  ...
#
#                          Team Starter 3                    Team Starter 4  \
# 0                   Air Force C. Medina          Air Force J. Satterfield
# 1                   Air Force C. Medina          Air Force J. Satterfield
# 2                   Air Force C. Medina          Air Force J. Satterfield
# 3                   Air Force C. Medina               Air Force M. O'Neil
# 4                   Air Force M. O'Neil              Air Force D. Sorrera
# ...                                 ...                               ...
# 10075         Youngstown State T. Jones  Youngstown State K. Middlebrooks
# 10076         Youngstown State T. Jones  Youngstown State K. Middlebrooks
# 10077    Youngstown State L. Hornberger  Youngstown State K. Middlebrooks
# 10078  Youngstown State K. Middlebrooks      Youngstown State H. Schlegel
# 10079  Youngstown State K. Middlebrooks      Youngstown State H. Schlegel
#
#                      Team Starter 5          Opponent Starter 1  \
# 0             Air Force C. Thompson          Lipscomb A. Bowers
# 1             Air Force C. Thompson  Tennessee-Martin H. Butler
# 2             Air Force C. Thompson            Denver M. Michel
# 3             Air Force C. Thompson    Texas Southern C. Anyiam
# 4             Air Force C. Thompson       Texas State D. Clinch
# ...                             ...                         ...
# 10075    Youngstown State M. Nortey          Green Bay L. Bauer
# 10076    Youngstown State M. Nortey        Wright State C. Boyd
# 10077  Youngstown State H. Schlegel      Detroit Mercy L. Allen
# 10078  Youngstown State M. Touvelle    Cleveland State J. Adams
# 10079  Youngstown State M. Thompson    Cleveland State J. Adams
#
#                  Opponent Starter 2           Opponent Starter 3  \
# 0              Lipscomb M. Faulkner         Lipscomb H. Phillips
# 1      Tennessee-Martin S. Crawford  Tennessee-Martin J. Haislip
# 2                 Denver K. Murdoch             Denver Q. Noonan
# 3         Texas Southern G. Fleming       Texas Southern A. Hall
# 4               Texas State A. Ezeh          Texas State D. Ford
# ...                             ...                          ...
# 10075            Green Bay M. Lukan        Green Bay H. Quilling
# 10076      Wright State K. Demmings          Wright State M. Fox
# 10077        Detroit Mercy S. Brown      Detroit Mercy M. Hatter
# 10078    Cleveland State C. Coleman     Cleveland State T. Keane
# 10079    Cleveland State C. Coleman     Cleveland State T. Keane
#
#               Opponent Starter 4           Opponent Starter 5  \
# 0              Lipscomb O. Smith      Lipscomb E. Thornsberry
# 1       Tennessee-Martin T. Hall  Tennessee-Martin J. Newsome
# 2                Denver M. Shell              Denver E. Smith
# 3      Texas Southern J. McQueen       Texas Southern K. West
# 4         Texas State I. Johnson          Texas State V. Kalu
# ...                          ...                          ...
# 10075       Green Bay A. Ritchie           Green Bay J. Wojta
# 10076    Wright State K. Lamotte     Wright State S. Sandifer
# 10077     Detroit Mercy J. Jones     Detroit Mercy S. Shearer
# 10078    Cleveland State H. King    Cleveland State S. Winton
# 10079    Cleveland State H. King    Cleveland State S. Winton
#
#       Score Differential Adjusted Score Differential
# 0                      9                    1.361013
# 1                    -24                    1.500000
# 2                     -2                    1.102120
# 3                     10                    1.381279
# 4                      8                    1.338710
# ...                  ...                         ...
# 10075                 -5                    1.253292
# 10076                -22                    1.500000
# 10077                 -3                    1.166625
# 10078                -10                    1.381279
# 10079                 -3                    1.166625
#
# [10080 rows x 23 columns]

# %%
df.to_parquet(f'../data/unprocessed/womens_starters/starters_{season}.parquet')

'Done'
# Out:
# 'Done'
