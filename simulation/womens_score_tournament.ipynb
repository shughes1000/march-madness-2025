# %% [markdown]
# # Women's Tournament Scoring

# %% [markdown]
# Using the model generated brackets, find the brackets that best perform against a hypothetical public pool.

# %% [markdown]
# ### Setup Data

# %%
season = 2024

playin_losers = (  # remove play-in losers from seeding data
    3357,  # Sacred Heart
    3162,  # Columbia
    3120,  # Auburn
    3221,  # Holy Cross
)

season
# Out:
# 2024

# %%
import pickle

with open(f'../data/simulations/mens/mens_simulation_{season}.pkl', 'rb') as f:
    simulation_data = pickle.load(f)

results = simulation_data['results']
candidates = simulation_data['candidates']
public = simulation_data['public']

del simulation_data

'Done'
# Out:
# 'Done'

# %%
def dict_to_tuple(d):
    """Get values of dictionary in a tuple, sorted by key"""
    return tuple(d[key] for key in sorted(d.keys()))

# %%
import numpy as np

results_array = np.array(tuple(dict_to_tuple(result) for result in results))

results_array.shape
# Out:
# (3000, 63)

# %%
candidates_array = np.array(tuple(dict_to_tuple(c) for c in candidates))

candidates_array.shape
# Out:
# (4000, 63)

# %%
public_array = np.array(tuple(dict_to_tuple(p) for p in public))

public_array.shape
# Out:
# (2000, 63)

# %% [markdown]
# ### Score Brackets

# %%
round_scores = np.array([10]*32 + [20]*16 + [40]*8 + [80]*4 + [160]*2 + [320]*1)

def score_brackets(brackets, ground_truth):
    """Score array of brackets compared to a bracket treated as ground truth"""
    return np.sum((brackets == ground_truth)*round_scores, axis=1)

# %%
from tqdm.autonotebook import tqdm

# each row is a public bracket and each column is the tournament simulation

public_scores = np.array(tuple(
    score_brackets(public_array, result) for result in tqdm(results_array)
)).transpose()

public_scores.shape
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_17804\1627080850.py:1: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/3000 [00:00<?, ?it/s]
# (2000, 3000)

# %%
# each row is a candidate bracket and each column is the tournament simulation

candidates_scores = np.array(tuple(
    score_brackets(candidates_array, result) for result in tqdm(results_array)
)).transpose()

candidates_scores.shape
# Out:
#   0%|          | 0/3000 [00:00<?, ?it/s]
# (4000, 3000)

# %%
def get_best_brackets(pool_size: int, number_of_brackets: int, first_payout: int, second_payout: int, third_payout: int):
    """
    Get the best n possible brackets for a given pool size. 
    Subsequent brackets choices will headge previous bracket choices. 
    """
    third_place = np.quantile(public_scores, q=1-3/pool_size, axis=0)
    second_place = np.quantile(public_scores, q=1-2/pool_size, axis=0)
    first_place = np.quantile(public_scores, q=1-1/pool_size, axis=0)

    candidates_prizes = (
        (candidates_scores > third_place)*(third_payout) + 
        (candidates_scores > second_place)*(second_payout - third_payout) + 
        (candidates_scores > first_place)*(first_payout - second_payout)
    )

    best_brackets = []  # indexes of best brackets from candidates
    for _ in tqdm(range(number_of_brackets)):
        best_available_bracket = candidates_prizes.mean(axis=1).argmax()  # index of best available bracket given previous brackets selected
        prize = candidates_prizes.mean(axis=1)[best_available_bracket]
        best_brackets.append((best_available_bracket, prize))

        # hedging: remove any ground truths that the best available bracket won in
        ignore_indexes = np.where(candidates_prizes[best_available_bracket] != 0)[0]
        candidates_prizes = np.delete(candidates_prizes, ignore_indexes, axis=1)

    return best_brackets

# %%
bb = get_best_brackets(
    pool_size=100, 
    number_of_brackets=25, 
    first_payout=85, 
    second_payout=12, 
    third_payout=3,
)

bb
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# [(2413, 5.027),
#  (3516, 3.3360594795539034),
#  (1589, 3.394086674767112),
#  (1754, 3.0273081924577374),
#  (1594, 3.068582020389249),
#  (3034, 2.904382470119522),
#  (2555, 3.0230810520665594),
#  (3006, 2.9668539325842698),
#  (2337, 3.0407047387606316),
#  (3367, 3.1619537275064267),
#  (3686, 3.234492160872529),
#  (3986, 3.356669123065586),
#  (1270, 3.6897959183673468),
#  (3923, 3.7563318777292576),
#  (3969, 3.9745762711864407),
#  (2751, 4.067901234567901),
#  (3016, 3.840834248079034),
#  (3463, 4.221014492753623),
#  (2204, 4.509536784741145),
#  (2241, 4.611026033690658),
#  (2915, 4.5245098039215685),
#  (3581, 4.346715328467154),
#  (3850, 4.421052631578948),
#  (2902, 4.825431034482759),
#  (3173, 4.776470588235294)]

# %% [markdown]
# ### Display Brackets

# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_teams = df_teams = pd.read_csv(r'..\data\unprocessed\kaggle\WTeams.csv')

df_teams
# Out:
#      TeamID        TeamName
# 0      3101     Abilene Chr
# 1      3102       Air Force
# 2      3103           Akron
# 3      3104         Alabama
# 4      3105     Alabama A&M
# ..      ...             ...
# 373    3476       Stonehill
# 374    3477  East Texas A&M
# 375    3478        Le Moyne
# 376    3479      Mercyhurst
# 377    3480    West Georgia
#
# [378 rows x 2 columns]

# %%
df_seeds = pd.read_csv(r'..\data\unprocessed\kaggle\WNCAATourneySeeds.csv')

df_seeds = df_seeds.loc[df_seeds['Season'] == season, :].reset_index(drop=True)

df_seeds.insert(2, 'Play In', df_seeds['Seed'].str.endswith(('a', 'b')))
df_seeds.insert(2, 'Region', df_seeds['Seed'].str[0])
df_seeds['Seed'] = df_seeds['Seed'].str.extract('(\d+)').astype(int)

df_seeds = df_seeds.loc[~df_seeds['TeamID'].isin(playin_losers), :].reset_index(drop=True)

df_seeds.insert(1, 'Region Seed', df_seeds['Region'] + df_seeds['Seed'].astype(str).str.zfill(2))

df_seeds
# Out:
#     Season Region Seed  Seed Region  Play In  TeamID
# 0     2024         W01     1      W    False    3376
# 1     2024         W02     2      W    False    3323
# 2     2024         W03     3      W    False    3333
# 3     2024         W04     4      W    False    3231
# 4     2024         W05     5      W    False    3328
# ..     ...         ...   ...    ...      ...     ...
# 59    2024         Z12    12      Z     True    3435
# 60    2024         Z13    13      Z    False    3267
# 61    2024         Z14    14      Z    False    3238
# 62    2024         Z15    15      Z    False    3263
# 63    2024         Z16    16      Z    False    3394
#
# [64 rows x 6 columns]

# %%
id_to_team = dict(zip(df_teams['TeamID'], df_teams['TeamName']))
region_seed_to_team = dict(zip(df_seeds['Region Seed'], df_seeds['TeamID'].map(id_to_team)))

len(region_seed_to_team)
# Out:
# 64

# %%
def display_bracket(bracket):
    display_dict = {game: region_seed_to_team[region_seed] for game, region_seed in bracket.items()}

    print('-'*30)
    print()
    print('ROUND OF 64 WINNERS')
    print()
    for region in ('W', 'X', 'Y', 'Z'):
        print(f'REGION {region}')
        for slot in (1, 8, 5, 4, 6, 3, 7, 2):
            key = f'R1{region}{slot}'
            print(f'{key}: {display_dict[key]}')
        print()
    print('-'*30)
    print()

    print('ROUND OF 32 WINNERS')
    print()
    for region in ('W', 'X', 'Y', 'Z'):
        print(f'REGION {region}')
        for slot in (1, 4, 3, 2):
            key = f'R2{region}{slot}'
            print(f'{key}: {display_dict[key]}')
        print()
    print('-'*30)
    print()

    print('ROUND OF 16 WINNERS')
    print()
    for region in ('W', 'X', 'Y', 'Z'):
        print(f'REGION {region}')
        for slot in (1, 2):
            key = f'R3{region}{slot}'
            print(f'{key}: {display_dict[key]}')
        print()
    print('-'*30)
    print()

    print('ELITE EIGHT WINNERS')
    print()
    for region in ('W', 'X', 'Y', 'Z'):
        print(f'REGION {region}')
        for slot in (1, ):
            key = f'R4{region}{slot}'
            print(f'{key}: {display_dict[key]}')
        print()
    print('-'*30)
    print()

    print('FINAL FOUR WINNERS')
    print()
    for matchup in ('WX', 'YZ'):
        key = f'R5{matchup}'
        print(f'{key}: {display_dict[key]}')
        print()
    print('-'*30)
    print()

    print('FINALS WINNER')
    print()
    for matchup in ('CH', ):
        key = f'R6{matchup}'
        print(f'{key}: {display_dict[key]}')
        print()
    print('-'*30)
    print()

# %%
for index, (b, _) in enumerate(bb):
    print(f'BRACKET {index+1}\n')
    display_bracket(candidates[b])
# Out:
# BRACKET 1
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Marquette
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: S Dakota St
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Iowa St
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: West Virginia
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: MTSU
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Kansas
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Richmond
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: Indiana
# R3W2: Oregon St
#
# REGION X
# R3X1: Texas
# R3X2: Stanford
#
# REGION Y
# R3Y1: Iowa
# R3Y2: LSU
#
# REGION Z
# R3Z1: USC
# R3Z2: Connecticut
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: Indiana
#
# REGION X
# R4X1: Stanford
#
# REGION Y
# R4Y1: Iowa
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: Stanford
#
# R5YZ: USC
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: USC
#
# ------------------------------
#
# BRACKET 2
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: Michigan St
# R1W5: FGCU
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Marquette
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: West Virginia
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: UNLV
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Kansas
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Duke
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Oregon St
#
# REGION X
# R3X1: Gonzaga
# R3X2: Stanford
#
# REGION Y
# R3Y1: Iowa
# R3Y2: UCLA
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Stanford
#
# REGION Y
# R4Y1: UCLA
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: South Carolina
#
# R5YZ: USC
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: USC
#
# ------------------------------
#
# BRACKET 3
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: Michigan St
# R1W5: FGCU
# R1W4: Indiana
# R1W6: Texas A&M
# R1W3: Oregon St
# R1W7: Marquette
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Alabama
# R1X5: S Dakota St
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: West Virginia
# R1Y5: Colorado
# R1Y4: Portland
# R1Y6: MTSU
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Arizona
# R1Z3: Connecticut
# R1Z7: Richmond
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Arizona
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Oregon St
#
# REGION X
# R3X1: Gonzaga
# R3X2: NC State
#
# REGION Y
# R3Y1: Iowa
# R3Y2: LSU
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: NC State
#
# REGION Y
# R4Y1: LSU
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: NC State
#
# R5YZ: LSU
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: LSU
#
# ------------------------------
#
# BRACKET 4
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: Michigan St
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: E Washington
# R1W7: Mississippi
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Iowa St
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: West Virginia
# R1Y5: Colorado
# R1Y4: Portland
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Kansas
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Arizona
# R1Z3: Connecticut
# R1Z7: Richmond
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Nebraska
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: Tennessee
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Notre Dame
#
# REGION X
# R3X1: Gonzaga
# R3X2: Stanford
#
# REGION Y
# R3Y1: Iowa
# R3Y2: UCLA
#
# REGION Z
# R3Z1: Virginia Tech
# R3Z2: Connecticut
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Gonzaga
#
# REGION Y
# R4Y1: Iowa
#
# REGION Z
# R4Z1: Virginia Tech
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: South Carolina
#
# R5YZ: Virginia Tech
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: South Carolina
#
# ------------------------------
#
# BRACKET 5
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: Michigan St
# R1W5: FGCU
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Marquette
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: S Dakota St
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Iowa St
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: West Virginia
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: UNLV
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Richmond
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Florida St
# R2X4: Gonzaga
# R2X3: Tennessee
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Baylor
# R2Z3: Syracuse
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: Indiana
# R3W2: Notre Dame
#
# REGION X
# R3X1: Gonzaga
# R3X2: Stanford
#
# REGION Y
# R3Y1: Iowa
# R3Y2: UCLA
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: Notre Dame
#
# REGION X
# R4X1: Gonzaga
#
# REGION Y
# R4Y1: Iowa
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: Gonzaga
#
# R5YZ: Iowa
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: Iowa
#
# ------------------------------
#
# BRACKET 6
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: Michigan St
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Marquette
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: Princeton
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Duke
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: Tennessee
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Oregon St
#
# REGION X
# R3X1: Gonzaga
# R3X2: Stanford
#
# REGION Y
# R3Y1: Colorado
# R3Y2: UCLA
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Stanford
#
# REGION Y
# R4Y1: UCLA
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: South Carolina
#
# R5YZ: USC
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: South Carolina
#
# ------------------------------
#
# BRACKET 7
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: FGCU
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Mississippi
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Alabama
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: WI Green Bay
# R1X3: NC State
# R1X7: Iowa St
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: Princeton
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: MTSU
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Kansas
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Arizona
# R1Z3: Connecticut
# R1Z7: Duke
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Mississippi
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: WI Green Bay
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Kansas St
# R2Y3: MTSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: Indiana
# R3W2: Oregon St
#
# REGION X
# R3X1: Texas
# R3X2: Stanford
#
# REGION Y
# R3Y1: Iowa
# R3Y2: UCLA
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: Indiana
#
# REGION X
# R4X1: Texas
#
# REGION Y
# R4Y1: Iowa
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: Indiana
#
# R5YZ: USC
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: Indiana
#
# ------------------------------
#
# BRACKET 8
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Texas A&M
# R1W3: Oregon St
# R1W7: Mississippi
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: S Dakota St
# R1X4: Gonzaga
# R1X6: WI Green Bay
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: Princeton
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: MTSU
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Vanderbilt
# R1Z4: Virginia Tech
# R1Z6: Arizona
# R1Z3: Connecticut
# R1Z7: Duke
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Oklahoma
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Kansas St
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Notre Dame
#
# REGION X
# R3X1: Texas
# R3X2: NC State
#
# REGION Y
# R3Y1: Iowa
# R3Y2: LSU
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Texas
#
# REGION Y
# R4Y1: Iowa
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: South Carolina
#
# R5YZ: Iowa
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: South Carolina
#
# ------------------------------
#
# BRACKET 9
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Marquette
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: Princeton
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: MTSU
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Duke
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: Tennessee
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Kansas St
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Oregon St
#
# REGION X
# R3X1: Gonzaga
# R3X2: Stanford
#
# REGION Y
# R3Y1: Iowa
# R3Y2: UCLA
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Stanford
#
# REGION Y
# R4Y1: UCLA
#
# REGION Z
# R4Z1: Ohio St
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: South Carolina
#
# R5YZ: Ohio St
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: Ohio St
#
# ------------------------------
#
# BRACKET 10
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Mississippi
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: WI Green Bay
# R1X3: NC State
# R1X7: Iowa St
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: Princeton
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: MTSU
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Duke
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Nebraska
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Kansas St
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Notre Dame
#
# REGION X
# R3X1: Texas
# R3X2: Stanford
#
# REGION Y
# R3Y1: Iowa
# R3Y2: LSU
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Texas
#
# REGION Y
# R4Y1: LSU
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: Texas
#
# R5YZ: USC
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: USC
#
# ------------------------------
#
# BRACKET 11
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: Michigan St
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Mississippi
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: WI Green Bay
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: Princeton
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Arizona
# R1Z3: Connecticut
# R1Z7: Duke
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: WI Green Bay
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Kansas St
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Baylor
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Notre Dame
#
# REGION X
# R3X1: Texas
# R3X2: Stanford
#
# REGION Y
# R3Y1: Iowa
# R3Y2: UCLA
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Stanford
#
# REGION Y
# R4Y1: UCLA
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: Stanford
#
# R5YZ: USC
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: Stanford
#
# ------------------------------
#
# BRACKET 12
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: Michigan St
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Mississippi
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: WI Green Bay
# R1X3: NC State
# R1X7: Iowa St
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: West Virginia
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: MTSU
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Kansas
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Duke
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Notre Dame
#
# REGION X
# R3X1: Texas
# R3X2: Stanford
#
# REGION Y
# R3Y1: Iowa
# R3Y2: LSU
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Stanford
#
# REGION Y
# R4Y1: Iowa
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: South Carolina
#
# R5YZ: Iowa
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: Iowa
#
# ------------------------------
#
# BRACKET 13
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Mississippi
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: S Dakota St
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: Princeton
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Richmond
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Baylor
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Notre Dame
#
# REGION X
# R3X1: Texas
# R3X2: Stanford
#
# REGION Y
# R3Y1: Colorado
# R3Y2: LSU
#
# REGION Z
# R3Z1: USC
# R3Z2: Connecticut
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Texas
#
# REGION Y
# R4Y1: LSU
#
# REGION Z
# R4Z1: Connecticut
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: South Carolina
#
# R5YZ: LSU
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: South Carolina
#
# ------------------------------
#
# BRACKET 14
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Marquette
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: West Virginia
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Kansas
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Arizona
# R1Z3: Connecticut
# R1Z7: Duke
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Nebraska
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Utah
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Notre Dame
#
# REGION X
# R3X1: Texas
# R3X2: Stanford
#
# REGION Y
# R3Y1: Colorado
# R3Y2: UCLA
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: Notre Dame
#
# REGION X
# R4X1: Stanford
#
# REGION Y
# R4Y1: UCLA
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: Notre Dame
#
# R5YZ: USC
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: Notre Dame
#
# ------------------------------
#
# BRACKET 15
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Mississippi
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: Princeton
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Kansas
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Duke
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Oklahoma
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Utah
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: Louisville
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Notre Dame
#
# REGION X
# R3X1: Texas
# R3X2: Stanford
#
# REGION Y
# R3Y1: Iowa
# R3Y2: UCLA
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Stanford
#
# REGION Y
# R4Y1: UCLA
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: South Carolina
#
# R5YZ: UCLA
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: UCLA
#
# ------------------------------
#
# BRACKET 16
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Mississippi
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Iowa St
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: West Virginia
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Kansas
# R1Z5: Vanderbilt
# R1Z4: Virginia Tech
# R1Z6: Arizona
# R1Z3: Connecticut
# R1Z7: Duke
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Utah
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: Louisville
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Oregon St
#
# REGION X
# R3X1: Texas
# R3X2: Stanford
#
# REGION Y
# R3Y1: Iowa
# R3Y2: UCLA
#
# REGION Z
# R3Z1: USC
# R3Z2: Connecticut
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: Oregon St
#
# REGION X
# R4X1: Texas
#
# REGION Y
# R4Y1: Iowa
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: Oregon St
#
# R5YZ: Iowa
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: Oregon St
#
# ------------------------------
#
# BRACKET 17
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: FGCU
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Mississippi
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Alabama
# R1X5: S Dakota St
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: Princeton
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: MTSU
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Richmond
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Oregon St
#
# REGION X
# R3X1: Texas
# R3X2: Stanford
#
# REGION Y
# R3Y1: Iowa
# R3Y2: UCLA
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Texas
#
# REGION Y
# R4Y1: UCLA
#
# REGION Z
# R4Z1: Ohio St
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: South Carolina
#
# R5YZ: UCLA
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: South Carolina
#
# ------------------------------
#
# BRACKET 18
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Marquette
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Iowa St
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: Princeton
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: MTSU
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Richmond
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: MTSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Oregon St
#
# REGION X
# R3X1: Texas
# R3X2: NC State
#
# REGION Y
# R3Y1: Iowa
# R3Y2: UCLA
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: NC State
#
# REGION Y
# R4Y1: Iowa
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: South Carolina
#
# R5YZ: USC
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: USC
#
# ------------------------------
#
# BRACKET 19
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: Michigan St
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Texas A&M
# R1W3: Oregon St
# R1W7: Marquette
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: Princeton
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Duke
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Utah
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Oregon St
#
# REGION X
# R3X1: Texas
# R3X2: Stanford
#
# REGION Y
# R3Y1: Iowa
# R3Y2: LSU
#
# REGION Z
# R3Z1: USC
# R3Z2: Connecticut
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Texas
#
# REGION Y
# R4Y1: Iowa
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: South Carolina
#
# R5YZ: USC
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: South Carolina
#
# ------------------------------
#
# BRACKET 20
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Texas A&M
# R1W3: Oregon St
# R1W7: Mississippi
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: S Dakota St
# R1X4: Gonzaga
# R1X6: WI Green Bay
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: West Virginia
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: MTSU
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Duke
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Oklahoma
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Notre Dame
#
# REGION X
# R3X1: Texas
# R3X2: Stanford
#
# REGION Y
# R3Y1: Colorado
# R3Y2: UCLA
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: Notre Dame
#
# REGION X
# R4X1: Stanford
#
# REGION Y
# R4Y1: Colorado
#
# REGION Z
# R4Z1: Ohio St
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: Stanford
#
# R5YZ: Colorado
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: Colorado
#
# ------------------------------
#
# BRACKET 21
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: Michigan St
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Mississippi
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: West Virginia
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Kansas
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Richmond
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Nebraska
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Utah
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Kansas St
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Richmond
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Nebraska
#
# REGION X
# R3X1: Utah
# R3X2: Stanford
#
# REGION Y
# R3Y1: Iowa
# R3Y2: UCLA
#
# REGION Z
# R3Z1: Virginia Tech
# R3Z2: Connecticut
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Stanford
#
# REGION Y
# R4Y1: Iowa
#
# REGION Z
# R4Z1: Connecticut
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: South Carolina
#
# R5YZ: Iowa
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: South Carolina
#
# ------------------------------
#
# BRACKET 22
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Texas A&M
# R1W3: Oregon St
# R1W7: Marquette
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Alabama
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: WI Green Bay
# R1X3: NC State
# R1X7: Iowa St
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: West Virginia
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Vanderbilt
# R1Z4: Virginia Tech
# R1Z6: Arizona
# R1Z3: Connecticut
# R1Z7: Richmond
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Notre Dame
#
# REGION X
# R3X1: Texas
# R3X2: NC State
#
# REGION Y
# R3Y1: Iowa
# R3Y2: LSU
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Texas
#
# REGION Y
# R4Y1: Iowa
#
# REGION Z
# R4Z1: Ohio St
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: South Carolina
#
# R5YZ: Ohio St
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: South Carolina
#
# ------------------------------
#
# BRACKET 23
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Mississippi
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Alabama
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: WI Green Bay
# R1X3: NC State
# R1X7: Iowa St
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: West Virginia
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Arizona
# R1Z3: Connecticut
# R1Z7: Richmond
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Oklahoma
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: WI Green Bay
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Colorado
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Arizona
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Oregon St
#
# REGION X
# R3X1: Texas
# R3X2: Stanford
#
# REGION Y
# R3Y1: Colorado
# R3Y2: UCLA
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Texas
#
# REGION Y
# R4Y1: UCLA
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: Texas
#
# R5YZ: USC
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: Texas
#
# ------------------------------
#
# BRACKET 24
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Marquette
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Alabama
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: Tennessee
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: Princeton
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: UNLV
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Michigan
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Richmond
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Utah
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Kansas St
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Baylor
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Oregon St
#
# REGION X
# R3X1: Texas
# R3X2: NC State
#
# REGION Y
# R3Y1: Iowa
# R3Y2: UCLA
#
# REGION Z
# R3Z1: USC
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: South Carolina
#
# REGION X
# R4X1: Texas
#
# REGION Y
# R4Y1: Iowa
#
# REGION Z
# R4Z1: USC
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: Texas
#
# R5YZ: Iowa
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: Iowa
#
# ------------------------------
#
# BRACKET 25
#
# ------------------------------
#
# ROUND OF 64 WINNERS
#
# REGION W
# R1W1: South Carolina
# R1W8: North Carolina
# R1W5: Oklahoma
# R1W4: Indiana
# R1W6: Nebraska
# R1W3: Oregon St
# R1W7: Marquette
# R1W2: Notre Dame
#
# REGION X
# R1X1: Texas
# R1X8: Florida St
# R1X5: Utah
# R1X4: Gonzaga
# R1X6: WI Green Bay
# R1X3: NC State
# R1X7: Maryland
# R1X2: Stanford
#
# REGION Y
# R1Y1: Iowa
# R1Y8: Princeton
# R1Y5: Colorado
# R1Y4: Kansas St
# R1Y6: Louisville
# R1Y3: LSU
# R1Y7: Creighton
# R1Y2: UCLA
#
# REGION Z
# R1Z1: USC
# R1Z8: Kansas
# R1Z5: Baylor
# R1Z4: Virginia Tech
# R1Z6: Syracuse
# R1Z3: Connecticut
# R1Z7: Duke
# R1Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 32 WINNERS
#
# REGION W
# R2W1: South Carolina
# R2W4: Indiana
# R2W3: Oregon St
# R2W2: Notre Dame
#
# REGION X
# R2X1: Texas
# R2X4: Gonzaga
# R2X3: NC State
# R2X2: Stanford
#
# REGION Y
# R2Y1: Iowa
# R2Y4: Kansas St
# R2Y3: LSU
# R2Y2: UCLA
#
# REGION Z
# R2Z1: USC
# R2Z4: Virginia Tech
# R2Z3: Connecticut
# R2Z2: Ohio St
#
# ------------------------------
#
# ROUND OF 16 WINNERS
#
# REGION W
# R3W1: South Carolina
# R3W2: Oregon St
#
# REGION X
# R3X1: Texas
# R3X2: NC State
#
# REGION Y
# R3Y1: Kansas St
# R3Y2: UCLA
#
# REGION Z
# R3Z1: Virginia Tech
# R3Z2: Ohio St
#
# ------------------------------
#
# ELITE EIGHT WINNERS
#
# REGION W
# R4W1: Oregon St
#
# REGION X
# R4X1: Texas
#
# REGION Y
# R4Y1: UCLA
#
# REGION Z
# R4Z1: Virginia Tech
#
# ------------------------------
#
# FINAL FOUR WINNERS
#
# R5WX: Texas
#
# R5YZ: Virginia Tech
#
# ------------------------------
#
# FINALS WINNER
#
# R6CH: Virginia Tech
#
# ------------------------------
