# %% [markdown]
# # Get Women's Head-to-Head

# %% [markdown]
# Get head-to-head records and records against common opponents.

# %% [markdown]
# ### Head-to-Head

# %%
SEASON = 2025
INCLUDE_CURRENT_SEASON = True

# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df = pd.concat(
    [
        pd.read_parquet(fr'..\data\unprocessed\womens_sports_reference\full_season_sports_reference_{season}.parquet')
        .assign(Season=season)
        for season in range(2012, SEASON + INCLUDE_CURRENT_SEASON)
        if season != 2020  # tournament was cancelled
    ],
    ignore_index=True
)

df.insert(0, 'Season', df.pop('Season'))

df = df.loc[df['NCAA Tournament'] == 0, :].reset_index(drop=True)  # only include games before NCAA Tournament

df
# Out:
#         Season              Team       Date  NCAA Tournament  Location  \
# 0         2012         Air Force 2011-11-11                0        -1
# 1         2012         Air Force 2011-11-13                0        -1
# 2         2012         Air Force 2011-11-17                0         1
# 3         2012         Air Force 2011-11-19                0        -1
# 4         2012         Air Force 2011-11-21                0        -1
# ...        ...               ...        ...              ...       ...
# 133795    2025  Youngstown State 2025-02-20                0        -1
# 133796    2025  Youngstown State 2025-02-22                0        -1
# 133797    2025  Youngstown State 2025-02-26                0        -1
# 133798    2025  Youngstown State 2025-03-01                0         1
# 133799    2025  Youngstown State 2025-03-04                0        -1
#
#                 Opponent            Type  Result  Team Score  Opponent Score  \
# 0               Lipscomb  REG (Non-Conf)       1        68.0            59.0
# 1       Tennessee-Martin  REG (Non-Conf)      -1        60.0            84.0
# 2                 Denver  REG (Non-Conf)      -1        52.0            54.0
# 3         Texas Southern  REG (Non-Conf)       1        64.0            54.0
# 4            Texas State  REG (Non-Conf)       1        77.0            69.0
# ...                  ...             ...     ...         ...             ...
# 133795     Detroit Mercy      REG (Conf)       1        67.0            59.0
# 133796           Oakland      REG (Conf)       1        52.0            51.0
# 133797     Robert Morris      REG (Conf)      -1        53.0            76.0
# 133798   Cleveland State      REG (Conf)       1        73.0            70.0
# 133799      Wright State          CTOURN      -1        58.0            73.0
#
#         Team FG  Team FGA  Team FG%  Team 3P  Team 3PA  Team 3P%  Team 2P  \
# 0          23.0      63.0     0.365      1.0       4.0     0.250     22.0
# 1          27.0      64.0     0.422      4.0       8.0     0.500     23.0
# 2          20.0      60.0     0.333      1.0       8.0     0.125     19.0
# 3          20.0      51.0     0.392      0.0       2.0     0.000     20.0
# 4          25.0      61.0     0.410      1.0       6.0     0.167     24.0
# ...         ...       ...       ...      ...       ...       ...      ...
# 133795     26.0      49.0     0.531      4.0      11.0     0.364     22.0
# 133796     19.0      49.0     0.388      3.0      11.0     0.273     16.0
# 133797     18.0      55.0     0.327      5.0      18.0     0.278     13.0
# 133798     24.0      66.0     0.364      6.0      19.0     0.316     18.0
# 133799     21.0      52.0     0.404      4.0      11.0     0.364     17.0
#
#         Team 2PA  Team 2P%  Team eFG%  Team FT  Team FTA  Team FT%  Team ORB  \
# 0           59.0     0.373      0.373     21.0      30.0     0.700      15.0
# 1           56.0     0.411      0.453      2.0       4.0     0.500      12.0
# 2           52.0     0.365      0.342     11.0      20.0     0.550      14.0
# 3           49.0     0.408      0.392     24.0      33.0     0.727       8.0
# 4           55.0     0.436      0.418     26.0      31.0     0.839      16.0
# ...          ...       ...        ...      ...       ...       ...       ...
# 133795      38.0     0.579      0.571     11.0      16.0     0.688       5.0
# 133796      38.0     0.421      0.418     11.0      18.0     0.611       8.0
# 133797      37.0     0.351      0.373     12.0      14.0     0.857      10.0
# 133798      47.0     0.383      0.409     19.0      22.0     0.864      14.0
# 133799      41.0     0.415      0.442     12.0      18.0     0.667       4.0
#
#         Team DRB  Team TRB  Team AST  Team STL  Team BLK  Team TOV  Team PF  \
# 0           26.0      41.0      11.0      11.0       2.0      16.0     23.0
# 1           23.0      35.0      17.0      10.0       1.0      27.0     16.0
# 2           34.0      48.0      15.0       7.0       3.0      21.0     26.0
# 3           27.0      35.0      13.0      14.0       1.0      21.0     20.0
# 4           29.0      45.0      10.0       9.0       3.0      19.0     21.0
# ...          ...       ...       ...       ...       ...       ...      ...
# 133795      30.0      35.0      12.0       8.0       1.0      22.0     10.0
# 133796      26.0      34.0       9.0       8.0       3.0      19.0     13.0
# 133797      21.0      31.0      12.0       6.0       0.0      17.0     15.0
# 133798      19.0      33.0      17.0       6.0       2.0       5.0     16.0
# 133799      20.0      24.0      10.0       9.0       4.0      12.0     12.0
#
#         Opponent FG  Opponent FGA  Opponent FG%  Opponent 3P  Opponent 3PA  \
# 0              18.0          54.0         0.333          4.0          12.0
# 1              32.0          69.0         0.464         10.0          30.0
# 2              20.0          57.0         0.351          1.0          10.0
# 3              17.0          57.0         0.298          5.0          18.0
# 4              27.0          67.0         0.403          4.0          21.0
# ...             ...           ...           ...          ...           ...
# 133795         23.0          66.0         0.348          5.0          23.0
# 133796         20.0          59.0         0.339          6.0          16.0
# 133797         29.0          57.0         0.509         10.0          22.0
# 133798         23.0          54.0         0.426          9.0          27.0
# 133799         26.0          61.0         0.426         10.0          23.0
#
#         Opponent 3P%  Opponent 2P  Opponent 2PA  Opponent 2P%  Opponent eFG%  \
# 0              0.333         14.0          42.0         0.333          0.370
# 1              0.333         22.0          39.0         0.564          0.536
# 2              0.100         19.0          47.0         0.404          0.360
# 3              0.278         12.0          39.0         0.308          0.342
# 4              0.190         23.0          46.0         0.500          0.433
# ...              ...          ...           ...           ...            ...
# 133795         0.217         18.0          43.0         0.419          0.386
# 133796         0.375         14.0          43.0         0.326          0.390
# 133797         0.455         19.0          35.0         0.543          0.596
# 133798         0.333         14.0          27.0         0.519          0.509
# 133799         0.435         16.0          38.0         0.421          0.508
#
#         Opponent FT  Opponent FTA  Opponent FT%  Opponent ORB  Opponent DRB  \
# 0              19.0          31.0         0.613          13.0          23.0
# 1              10.0          11.0         0.909           9.0          22.0
# 2              13.0          30.0         0.433          10.0          32.0
# 3              15.0          24.0         0.625          15.0          26.0
# 4              11.0          20.0         0.550          13.0          17.0
# ...             ...           ...           ...           ...           ...
# 133795          8.0           9.0         0.889          10.0          17.0
# 133796          5.0           6.0         0.833           7.0          23.0
# 133797          8.0          13.0         0.615           7.0          27.0
# 133798         15.0          20.0         0.750           8.0          26.0
# 133799         11.0          13.0         0.846          15.0          28.0
#
#         Opponent TRB  Opponent AST  Opponent STL  Opponent BLK  Opponent TOV  \
# 0               36.0          10.0           8.0           3.0          23.0
# 1               31.0          15.0          12.0           4.0          18.0
# 2               42.0          16.0          13.0           4.0          20.0
# 3               41.0          13.0          10.0           6.0          30.0
# 4               30.0          10.0           8.0           2.0          14.0
# ...              ...           ...           ...           ...           ...
# 133795          27.0          10.0          10.0           3.0          14.0
# 133796          30.0          10.0          10.0           4.0          13.0
# 133797          34.0          19.0           8.0           6.0          13.0
# 133798          34.0          20.0           3.0           7.0          11.0
# 133799          43.0          14.0           7.0           4.0          16.0
#
#         Opponent PF  Overtimes Amount  Overtime  Score Differential  \
# 0              24.0                 0         0                 9.0
# 1               7.0                 0         0               -24.0
# 2              19.0                 0         0                -2.0
# 3              27.0                 0         0                10.0
# 4              20.0                 0         0                 8.0
# ...             ...               ...       ...                 ...
# 133795         21.0                 0         0                 8.0
# 133796         19.0                 0         0                 1.0
# 133797         15.0                 0         0               -23.0
# 133798         21.0                 0         0                 3.0
# 133799         15.0                 0         0               -15.0
#
#         Adjusted Score Differential  Possessions  Team PPP  Opponent PPP  \
# 0                          1.361013        77.42  0.878326      0.762077
# 1                          1.500000        81.80  0.733496      1.026895
# 2                          1.102120        78.00  0.666667      0.692308
# 3                          1.381279        80.54  0.794636      0.670474
# 4                          1.338710        77.22  0.997151      0.893551
# ...                             ...          ...       ...           ...
# 133795                     1.338710        73.50  0.911565      0.802721
# 133796                     1.000000        67.78  0.767188      0.752434
# 133797                     1.500000        68.44  0.774401      1.110462
# 133798                     1.166625        66.24  1.102053      1.056763
# 133799                     1.462122        67.82  0.855205      1.076379
#
#         Tempo
# 0       77.42
# 1       81.80
# 2       78.00
# 3       80.54
# 4       77.22
# ...       ...
# 133795  73.50
# 133796  67.78
# 133797  68.44
# 133798  66.24
# 133799  67.82
#
# [133800 rows x 60 columns]

# %%
def rescale_weights(arr, minimum, maximum):
    """
    Rescale the weights array to match desired weights.
    Assumes the data is already transformed where a 1 point win is 1.00, a blowout is 1.50, and a tie is 0.50.
    Ties will be weighted as half the minimum.
    """

    arr_scaled = ((arr - 1.00) / 0.50) * (maximum - minimum) + minimum
    arr_scaled[arr == 0.50] = minimum / 2
    return arr_scaled

# make sure losses have negative adjusted score differential in this file
df['Adjusted Score Differential'] = rescale_weights(df['Adjusted Score Differential'], 0.50, 1.00)*df['Result']

df
# Out:
#         Season              Team       Date  NCAA Tournament  Location  \
# 0         2012         Air Force 2011-11-11                0        -1
# 1         2012         Air Force 2011-11-13                0        -1
# 2         2012         Air Force 2011-11-17                0         1
# 3         2012         Air Force 2011-11-19                0        -1
# 4         2012         Air Force 2011-11-21                0        -1
# ...        ...               ...        ...              ...       ...
# 133795    2025  Youngstown State 2025-02-20                0        -1
# 133796    2025  Youngstown State 2025-02-22                0        -1
# 133797    2025  Youngstown State 2025-02-26                0        -1
# 133798    2025  Youngstown State 2025-03-01                0         1
# 133799    2025  Youngstown State 2025-03-04                0        -1
#
#                 Opponent            Type  Result  Team Score  Opponent Score  \
# 0               Lipscomb  REG (Non-Conf)       1        68.0            59.0
# 1       Tennessee-Martin  REG (Non-Conf)      -1        60.0            84.0
# 2                 Denver  REG (Non-Conf)      -1        52.0            54.0
# 3         Texas Southern  REG (Non-Conf)       1        64.0            54.0
# 4            Texas State  REG (Non-Conf)       1        77.0            69.0
# ...                  ...             ...     ...         ...             ...
# 133795     Detroit Mercy      REG (Conf)       1        67.0            59.0
# 133796           Oakland      REG (Conf)       1        52.0            51.0
# 133797     Robert Morris      REG (Conf)      -1        53.0            76.0
# 133798   Cleveland State      REG (Conf)       1        73.0            70.0
# 133799      Wright State          CTOURN      -1        58.0            73.0
#
#         Team FG  Team FGA  Team FG%  Team 3P  Team 3PA  Team 3P%  Team 2P  \
# 0          23.0      63.0     0.365      1.0       4.0     0.250     22.0
# 1          27.0      64.0     0.422      4.0       8.0     0.500     23.0
# 2          20.0      60.0     0.333      1.0       8.0     0.125     19.0
# 3          20.0      51.0     0.392      0.0       2.0     0.000     20.0
# 4          25.0      61.0     0.410      1.0       6.0     0.167     24.0
# ...         ...       ...       ...      ...       ...       ...      ...
# 133795     26.0      49.0     0.531      4.0      11.0     0.364     22.0
# 133796     19.0      49.0     0.388      3.0      11.0     0.273     16.0
# 133797     18.0      55.0     0.327      5.0      18.0     0.278     13.0
# 133798     24.0      66.0     0.364      6.0      19.0     0.316     18.0
# 133799     21.0      52.0     0.404      4.0      11.0     0.364     17.0
#
#         Team 2PA  Team 2P%  Team eFG%  Team FT  Team FTA  Team FT%  Team ORB  \
# 0           59.0     0.373      0.373     21.0      30.0     0.700      15.0
# 1           56.0     0.411      0.453      2.0       4.0     0.500      12.0
# 2           52.0     0.365      0.342     11.0      20.0     0.550      14.0
# 3           49.0     0.408      0.392     24.0      33.0     0.727       8.0
# 4           55.0     0.436      0.418     26.0      31.0     0.839      16.0
# ...          ...       ...        ...      ...       ...       ...       ...
# 133795      38.0     0.579      0.571     11.0      16.0     0.688       5.0
# 133796      38.0     0.421      0.418     11.0      18.0     0.611       8.0
# 133797      37.0     0.351      0.373     12.0      14.0     0.857      10.0
# 133798      47.0     0.383      0.409     19.0      22.0     0.864      14.0
# 133799      41.0     0.415      0.442     12.0      18.0     0.667       4.0
#
#         Team DRB  Team TRB  Team AST  Team STL  Team BLK  Team TOV  Team PF  \
# 0           26.0      41.0      11.0      11.0       2.0      16.0     23.0
# 1           23.0      35.0      17.0      10.0       1.0      27.0     16.0
# 2           34.0      48.0      15.0       7.0       3.0      21.0     26.0
# 3           27.0      35.0      13.0      14.0       1.0      21.0     20.0
# 4           29.0      45.0      10.0       9.0       3.0      19.0     21.0
# ...          ...       ...       ...       ...       ...       ...      ...
# 133795      30.0      35.0      12.0       8.0       1.0      22.0     10.0
# 133796      26.0      34.0       9.0       8.0       3.0      19.0     13.0
# 133797      21.0      31.0      12.0       6.0       0.0      17.0     15.0
# 133798      19.0      33.0      17.0       6.0       2.0       5.0     16.0
# 133799      20.0      24.0      10.0       9.0       4.0      12.0     12.0
#
#         Opponent FG  Opponent FGA  Opponent FG%  Opponent 3P  Opponent 3PA  \
# 0              18.0          54.0         0.333          4.0          12.0
# 1              32.0          69.0         0.464         10.0          30.0
# 2              20.0          57.0         0.351          1.0          10.0
# 3              17.0          57.0         0.298          5.0          18.0
# 4              27.0          67.0         0.403          4.0          21.0
# ...             ...           ...           ...          ...           ...
# 133795         23.0          66.0         0.348          5.0          23.0
# 133796         20.0          59.0         0.339          6.0          16.0
# 133797         29.0          57.0         0.509         10.0          22.0
# 133798         23.0          54.0         0.426          9.0          27.0
# 133799         26.0          61.0         0.426         10.0          23.0
#
#         Opponent 3P%  Opponent 2P  Opponent 2PA  Opponent 2P%  Opponent eFG%  \
# 0              0.333         14.0          42.0         0.333          0.370
# 1              0.333         22.0          39.0         0.564          0.536
# 2              0.100         19.0          47.0         0.404          0.360
# 3              0.278         12.0          39.0         0.308          0.342
# 4              0.190         23.0          46.0         0.500          0.433
# ...              ...          ...           ...           ...            ...
# 133795         0.217         18.0          43.0         0.419          0.386
# 133796         0.375         14.0          43.0         0.326          0.390
# 133797         0.455         19.0          35.0         0.543          0.596
# 133798         0.333         14.0          27.0         0.519          0.509
# 133799         0.435         16.0          38.0         0.421          0.508
#
#         Opponent FT  Opponent FTA  Opponent FT%  Opponent ORB  Opponent DRB  \
# 0              19.0          31.0         0.613          13.0          23.0
# 1              10.0          11.0         0.909           9.0          22.0
# 2              13.0          30.0         0.433          10.0          32.0
# 3              15.0          24.0         0.625          15.0          26.0
# 4              11.0          20.0         0.550          13.0          17.0
# ...             ...           ...           ...           ...           ...
# 133795          8.0           9.0         0.889          10.0          17.0
# 133796          5.0           6.0         0.833           7.0          23.0
# 133797          8.0          13.0         0.615           7.0          27.0
# 133798         15.0          20.0         0.750           8.0          26.0
# 133799         11.0          13.0         0.846          15.0          28.0
#
#         Opponent TRB  Opponent AST  Opponent STL  Opponent BLK  Opponent TOV  \
# 0               36.0          10.0           8.0           3.0          23.0
# 1               31.0          15.0          12.0           4.0          18.0
# 2               42.0          16.0          13.0           4.0          20.0
# 3               41.0          13.0          10.0           6.0          30.0
# 4               30.0          10.0           8.0           2.0          14.0
# ...              ...           ...           ...           ...           ...
# 133795          27.0          10.0          10.0           3.0          14.0
# 133796          30.0          10.0          10.0           4.0          13.0
# 133797          34.0          19.0           8.0           6.0          13.0
# 133798          34.0          20.0           3.0           7.0          11.0
# 133799          43.0          14.0           7.0           4.0          16.0
#
#         Opponent PF  Overtimes Amount  Overtime  Score Differential  \
# 0              24.0                 0         0                 9.0
# 1               7.0                 0         0               -24.0
# 2              19.0                 0         0                -2.0
# 3              27.0                 0         0                10.0
# 4              20.0                 0         0                 8.0
# ...             ...               ...       ...                 ...
# 133795         21.0                 0         0                 8.0
# 133796         19.0                 0         0                 1.0
# 133797         15.0                 0         0               -23.0
# 133798         21.0                 0         0                 3.0
# 133799         15.0                 0         0               -15.0
#
#         Adjusted Score Differential  Possessions  Team PPP  Opponent PPP  \
# 0                          0.861013        77.42  0.878326      0.762077
# 1                         -1.000000        81.80  0.733496      1.026895
# 2                         -0.602120        78.00  0.666667      0.692308
# 3                          0.881279        80.54  0.794636      0.670474
# 4                          0.838710        77.22  0.997151      0.893551
# ...                             ...          ...       ...           ...
# 133795                     0.838710        73.50  0.911565      0.802721
# 133796                     0.500000        67.78  0.767188      0.752434
# 133797                    -1.000000        68.44  0.774401      1.110462
# 133798                     0.666625        66.24  1.102053      1.056763
# 133799                    -0.962122        67.82  0.855205      1.076379
#
#         Tempo
# 0       77.42
# 1       81.80
# 2       78.00
# 3       80.54
# 4       77.22
# ...       ...
# 133795  73.50
# 133796  67.78
# 133797  68.44
# 133798  66.24
# 133799  67.82
#
# [133800 rows x 60 columns]

# %%
df_h2h = (
    df
    .groupby(['Season', 'Team', 'Opponent'])
    .agg(
        h2h_sum=('Adjusted Score Differential', 'sum'),
        h2h_count=('Result', 'count')
    )
    .reset_index()
    .rename(columns={'Team': 'Team A', 'Opponent': 'Team B'})
)

# add 1/4 to denominator so that a team that beats opponent multiple times is better accounted for
df_h2h['Head to Head'] = df_h2h['h2h_sum'] / (df_h2h['h2h_count'] + 1/4)

df_h2h
# Out:
#        Season            Team A            Team B   h2h_sum  h2h_count  \
# 0        2012         Air Force           Alabama -1.000000          1
# 1        2012         Air Force       Boise State -1.785760          2
# 2        2012         Air Force    Colorado State -2.000000          2
# 3        2012         Air Force            Denver -0.602120          1
# 4        2012         Air Force     Jackson State  0.933063          1
# ...       ...               ...               ...       ...        ...
# 94945    2025  Youngstown State  Southern Indiana -1.000000          1
# 94946    2025  Youngstown State   St. Bonaventure  0.838710          1
# 94947    2025  Youngstown State            Towson -0.899871          1
# 94948    2025  Youngstown State      Wright State -2.526364          3
# 94949    2025  Youngstown State            Xavier -1.000000          1
#
#        Head to Head
# 0         -0.800000
# 1         -0.793671
# 2         -0.888889
# 3         -0.481696
# 4          0.746451
# ...             ...
# 94945     -0.800000
# 94946      0.670968
# 94947     -0.719897
# 94948     -0.777343
# 94949     -0.800000
#
# [94950 rows x 6 columns]

# %% [markdown]
# ### Common Opponents

# %%
df_h2h['h2h_avg'] = df_h2h['h2h_sum']/df_h2h['h2h_count']

df_h2h
# Out:
#        Season            Team A            Team B   h2h_sum  h2h_count  \
# 0        2012         Air Force           Alabama -1.000000          1
# 1        2012         Air Force       Boise State -1.785760          2
# 2        2012         Air Force    Colorado State -2.000000          2
# 3        2012         Air Force            Denver -0.602120          1
# 4        2012         Air Force     Jackson State  0.933063          1
# ...       ...               ...               ...       ...        ...
# 94945    2025  Youngstown State  Southern Indiana -1.000000          1
# 94946    2025  Youngstown State   St. Bonaventure  0.838710          1
# 94947    2025  Youngstown State            Towson -0.899871          1
# 94948    2025  Youngstown State      Wright State -2.526364          3
# 94949    2025  Youngstown State            Xavier -1.000000          1
#
#        Head to Head   h2h_avg
# 0         -0.800000 -1.000000
# 1         -0.793671 -0.892880
# 2         -0.888889 -1.000000
# 3         -0.481696 -0.602120
# 4          0.746451  0.933063
# ...             ...       ...
# 94945     -0.800000 -1.000000
# 94946      0.670968  0.838710
# 94947     -0.719897 -0.899871
# 94948     -0.777343 -0.842121
# 94949     -0.800000 -1.000000
#
# [94950 rows x 7 columns]

# %%
def get_opponents_results(season, team):
    data = df_h2h.loc[
        (df_h2h['Season'] == season) & 
        (df_h2h['Team A'] == team), 
        :
    ]
    
    return dict(zip(
        data['Team B'],
        data['h2h_avg']
    ))

# %%
from tqdm.autonotebook import tqdm

season_team_opponents = {
    season: {
        team: get_opponents_results(season, team) 
        for team in df_h2h.loc[df_h2h['Season'] == season, 'Team A'].unique()
    } 
    for season in tqdm(df_h2h['Season'].unique())
}

len(season_team_opponents)
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_22416\755660832.py:1: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/13 [00:00<?, ?it/s]
# 13

# %%
import numpy as np

def get_difference(season, team_a, team_b):
    team_a_dict = season_team_opponents[season][team_a]
    team_b_dict = season_team_opponents[season][team_b]

    common_keys = team_a_dict.keys() & team_b_dict.keys()

    if len(common_keys) == 0:
        return np.nan, np.nan
    
    commons_opps_results = tuple(team_a_dict[key] - team_b_dict[key] for key in common_keys)

    return np.sum(commons_opps_results), (len(commons_opps_results))

# %%
common_opps = [
    (season, team_a, team_b, *get_difference(season, team_a, team_b))
    for season in tqdm(df_h2h['Season'].unique())
    for team_a in df_h2h.loc[df_h2h['Season'] == season, 'Team A'].unique()
    for team_b in df_h2h.loc[df_h2h['Season'] == season, 'Team A'].unique()  # could use Team B but shouldn't matter
    if team_a != team_b
]

common_opps[:5]
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]
# [(2012, 'Air Force', 'Akron', nan, nan),
#  (2012, 'Air Force', 'Alabama', nan, nan),
#  (2012, 'Air Force', 'Alabama A&M', 0.5871746800195029, 3),
#  (2012, 'Air Force', 'Alabama State', 0.1716690566331004, 3),
#  (2012, 'Air Force', 'Albany (NY)', nan, nan)]

# %%
df_common_opps = pd.DataFrame(
    common_opps,
    columns=['Season', 'Team A', 'Team B', 'common_opps_sum', 'common_opps_count'],
)

df_common_opps
# Out:
#          Season            Team A         Team B  common_opps_sum  \
# 0          2012         Air Force          Akron              NaN
# 1          2012         Air Force        Alabama              NaN
# 2          2012         Air Force    Alabama A&M         0.587175
# 3          2012         Air Force  Alabama State         0.171669
# 4          2012         Air Force    Albany (NY)              NaN
# ...         ...               ...            ...              ...
# 1598279    2025  Youngstown State        Wofford              NaN
# 1598280    2025  Youngstown State   Wright State         2.274026
# 1598281    2025  Youngstown State        Wyoming              NaN
# 1598282    2025  Youngstown State         Xavier        -0.123412
# 1598283    2025  Youngstown State           Yale              NaN
#
#          common_opps_count
# 0                      NaN
# 1                      NaN
# 2                      3.0
# 3                      3.0
# 4                      NaN
# ...                    ...
# 1598279                NaN
# 1598280                9.0
# 1598281                NaN
# 1598282                1.0
# 1598283                NaN
#
# [1598284 rows x 5 columns]

# %%
df_h2h = pd.merge(
    df_h2h.drop(columns=['h2h_avg']),
    df_common_opps,
    how='outer',
    on=['Season', 'Team A', 'Team B'],
)

df_h2h
# Out:
#          Season            Team A         Team B   h2h_sum  h2h_count  \
# 0          2012         Air Force          Akron       NaN        NaN
# 1          2012         Air Force        Alabama -1.000000        1.0
# 2          2012         Air Force    Alabama A&M       NaN        NaN
# 3          2012         Air Force  Alabama State       NaN        NaN
# 4          2012         Air Force    Albany (NY)       NaN        NaN
# ...         ...               ...            ...       ...        ...
# 1598279    2025  Youngstown State        Wofford       NaN        NaN
# 1598280    2025  Youngstown State   Wright State -2.526364        3.0
# 1598281    2025  Youngstown State        Wyoming       NaN        NaN
# 1598282    2025  Youngstown State         Xavier -1.000000        1.0
# 1598283    2025  Youngstown State           Yale       NaN        NaN
#
#          Head to Head  common_opps_sum  common_opps_count
# 0                 NaN              NaN                NaN
# 1           -0.800000              NaN                NaN
# 2                 NaN         0.587175                3.0
# 3                 NaN         0.171669                3.0
# 4                 NaN              NaN                NaN
# ...               ...              ...                ...
# 1598279           NaN              NaN                NaN
# 1598280     -0.777343         2.274026                9.0
# 1598281           NaN              NaN                NaN
# 1598282     -0.800000        -0.123412                1.0
# 1598283           NaN              NaN                NaN
#
# [1598284 rows x 8 columns]

# %%
# add 1/4 to denominator so that a team that beats opponent multiple times is better accounted for
df_h2h['Common Opps'] = df_h2h['common_opps_sum']/(df_h2h['common_opps_count'] + 1/4)

df_h2h
# Out:
#          Season            Team A         Team B   h2h_sum  h2h_count  \
# 0          2012         Air Force          Akron       NaN        NaN
# 1          2012         Air Force        Alabama -1.000000        1.0
# 2          2012         Air Force    Alabama A&M       NaN        NaN
# 3          2012         Air Force  Alabama State       NaN        NaN
# 4          2012         Air Force    Albany (NY)       NaN        NaN
# ...         ...               ...            ...       ...        ...
# 1598279    2025  Youngstown State        Wofford       NaN        NaN
# 1598280    2025  Youngstown State   Wright State -2.526364        3.0
# 1598281    2025  Youngstown State        Wyoming       NaN        NaN
# 1598282    2025  Youngstown State         Xavier -1.000000        1.0
# 1598283    2025  Youngstown State           Yale       NaN        NaN
#
#          Head to Head  common_opps_sum  common_opps_count  Common Opps
# 0                 NaN              NaN                NaN          NaN
# 1           -0.800000              NaN                NaN          NaN
# 2                 NaN         0.587175                3.0     0.180669
# 3                 NaN         0.171669                3.0     0.052821
# 4                 NaN              NaN                NaN          NaN
# ...               ...              ...                ...          ...
# 1598279           NaN              NaN                NaN          NaN
# 1598280     -0.777343         2.274026                9.0     0.245841
# 1598281           NaN              NaN                NaN          NaN
# 1598282     -0.800000        -0.123412                1.0    -0.098729
# 1598283           NaN              NaN                NaN          NaN
#
# [1598284 rows x 9 columns]

# %%
df_h2h.loc[(df_h2h['Season'] == 2024) & df_h2h['Team A'].str.contains('Connecticut'), :]
# Out:
#          Season                     Team A             Team B  h2h_sum  \
# 1354158    2024  Central Connecticut State  Abilene Christian      NaN
# 1354159    2024  Central Connecticut State          Air Force      NaN
# 1354160    2024  Central Connecticut State              Akron      NaN
# 1354161    2024  Central Connecticut State            Alabama      NaN
# 1354162    2024  Central Connecticut State        Alabama A&M      NaN
# ...         ...                        ...                ...      ...
# 1359897    2024                Connecticut       Wright State      NaN
# 1359898    2024                Connecticut            Wyoming      NaN
# 1359899    2024                Connecticut             Xavier      1.0
# 1359900    2024                Connecticut               Yale      NaN
# 1359901    2024                Connecticut   Youngstown State      NaN
#
#          h2h_count  Head to Head  common_opps_sum  common_opps_count  \
# 1354158        NaN           NaN              NaN                NaN
# 1354159        NaN           NaN              NaN                NaN
# 1354160        NaN           NaN              NaN                NaN
# 1354161        NaN           NaN        -0.214240                1.0
# 1354162        NaN           NaN              NaN                NaN
# ...            ...           ...              ...                ...
# 1359897        NaN           NaN              NaN                NaN
# 1359898        NaN           NaN         1.917062                1.0
# 1359899        1.0           0.8        17.844118                9.0
# 1359900        NaN           NaN         3.734353                2.0
# 1359901        NaN           NaN         0.051961                1.0
#
#          Common Opps
# 1354158          NaN
# 1354159          NaN
# 1354160          NaN
# 1354161    -0.171392
# 1354162          NaN
# ...              ...
# 1359897          NaN
# 1359898     1.533650
# 1359899     1.929094
# 1359900     1.659713
# 1359901     0.041569
#
# [718 rows x 9 columns]

# %% [markdown]
# Remove all the rows without data to reduce the dataframe size

# %%
df_h2h = df_h2h.loc[(df_h2h['Head to Head'].notna()) | (df_h2h['Common Opps'].notna()), :].reset_index(drop=True)

df_h2h
# Out:
#         Season            Team A            Team B   h2h_sum  h2h_count  \
# 0         2012         Air Force           Alabama -1.000000        1.0
# 1         2012         Air Force       Alabama A&M       NaN        NaN
# 2         2012         Air Force     Alabama State       NaN        NaN
# 3         2012         Air Force      Alcorn State       NaN        NaN
# 4         2012         Air Force          American       NaN        NaN
# ...        ...               ...               ...       ...        ...
# 808913    2025  Youngstown State  Western Michigan       NaN        NaN
# 808914    2025  Youngstown State    William & Mary       NaN        NaN
# 808915    2025  Youngstown State         Wisconsin       NaN        NaN
# 808916    2025  Youngstown State      Wright State -2.526364        3.0
# 808917    2025  Youngstown State            Xavier -1.000000        1.0
#
#         Head to Head  common_opps_sum  common_opps_count  Common Opps
# 0          -0.800000              NaN                NaN          NaN
# 1                NaN         0.587175                3.0     0.180669
# 2                NaN         0.171669                3.0     0.052821
# 3                NaN         1.179970                3.0     0.363068
# 4                NaN        -3.255768                2.0    -1.447008
# ...              ...              ...                ...          ...
# 808913           NaN         0.738126                2.0     0.328056
# 808914           NaN        -1.799741                1.0    -1.439793
# 808915           NaN        -2.831187                3.0    -0.871134
# 808916     -0.777343         2.274026                9.0     0.245841
# 808917     -0.800000        -0.123412                1.0    -0.098729
#
# [808918 rows x 9 columns]

# %%
df_h2h.drop(columns=['h2h_sum', 'h2h_count', 'common_opps_sum', 'common_opps_count'], inplace=True)

df_h2h
# Out:
#         Season            Team A            Team B  Head to Head  Common Opps
# 0         2012         Air Force           Alabama     -0.800000          NaN
# 1         2012         Air Force       Alabama A&M           NaN     0.180669
# 2         2012         Air Force     Alabama State           NaN     0.052821
# 3         2012         Air Force      Alcorn State           NaN     0.363068
# 4         2012         Air Force          American           NaN    -1.447008
# ...        ...               ...               ...           ...          ...
# 808913    2025  Youngstown State  Western Michigan           NaN     0.328056
# 808914    2025  Youngstown State    William & Mary           NaN    -1.439793
# 808915    2025  Youngstown State         Wisconsin           NaN    -0.871134
# 808916    2025  Youngstown State      Wright State     -0.777343     0.245841
# 808917    2025  Youngstown State            Xavier     -0.800000    -0.098729
#
# [808918 rows x 5 columns]

# %%
df_h2h.to_parquet('../data/preprocessed/womens_h2h/h2h.parquet')

'Done'
# Out:
# 'Done'
